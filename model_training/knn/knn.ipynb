# %%
# !pip install scikit-learn scipy numpy matplotlib
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Collecting scipy
#   Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
# Requirement already satisfied: numpy in /home/Recomm-project/imdbvenv/lib/python3.10/site-packages (2.2.3)
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Requirement already satisfied: joblib>=1.2.0 in /home/Recomm-project/imdbvenv/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Requirement already satisfied: packaging>=20.0 in /home/Recomm-project/imdbvenv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8
#   Using cached pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/Recomm-project/imdbvenv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/Recomm-project/imdbvenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: threadpoolctl, scipy, pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, scikit-learn, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.1.0 pyparsing-3.2.1 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.5.0

# %%
import pandas as pd
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix

# File paths
RATINGS_FILE = "../data/processed_rate_entries.csv"
ITEM_SIMILARITY_MODEL = "./item_similarity.pkl"

# %%
df = pd.read_csv(RATINGS_FILE)
df
# Out:
#                   timestamp  user_id                         movie_title  \
# 0       2025-02-28T03:36:48   265143  rare exports a christmas tale 2010
# 1       2025-02-28T03:36:49   284982                       far away 2001
# 2       2025-02-28T03:36:49   301905      the princess and the frog 2009
# 3       2025-02-28T03:36:50   104416                  soul assassin 2001
# 4       2025-02-28T03:36:51   251315                    civil brand 2003
# ...                     ...      ...                                 ...
# 462959  2025-03-03T00:35:35   318940                  the vanishing 1993
# 462960  2025-03-03T00:35:35    20815                     up in arms 1944
# 462961  2025-03-03T00:35:35   290958                        lucky 7 2003
# 462962  2025-03-03T00:35:35   220777                  the corruptor 1999
# 462963  2025-03-03T00:35:35   113826              full body massage 1995
#
#         rating
# 0            4
# 1            2
# 2            4
# 3            3
# 4            3
# ...        ...
# 462959       4
# 462960       4
# 462961       3
# 462962       2
# 462963       4
#
# [462964 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462964 entries, 0 to 462963
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   timestamp    462964 non-null  object
#  1   user_id      462964 non-null  int64
#  2   movie_title  462964 non-null  object
#  3   rating       462964 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 14.1+ MB

# %%
# Create a mapping of movie titles to indices
movie_mapping = {movie: idx for idx, movie in enumerate(df["movie_title"].unique())}
movie_mapping
# Out:
# {'rare exports a christmas tale 2010': 0,
#  'far away 2001': 1,
#  'the princess and the frog 2009': 2,
#  'soul assassin 2001': 3,
#  'civil brand 2003': 4,
#  'the lord of the rings the return of the king 2003': 5,
#  'logans run 1976': 6,
#  'even angels eat beans 1973': 7,
#  'interstellar 2014': 8,
#  'star wars 1977': 9,
#  'the goonies 1985': 10,
#  'lagaan once upon a time in india 2001': 11,
#  'raiders of the lost ark 1981': 12,
#  'the offence 1973': 13,
#  'mississippi mermaid 1969': 14,
#  'wreck-it ralph 2012': 15,
#  'american beauty 1999': 16,
#  'the town 2010': 17,
#  'a kiss before dying 1991': 18,
#  'pirates of the caribbean the curse of the black pearl 2003': 19,
#  'avatar 2009': 20,
#  'overnight 2003': 21,
#  'bells are ringing 1960': 22,
#  'crouching tiger_ hidden dragon 2000': 23,
#  'mountains of the moon 1990': 24,
#  'the sheriff and the satellite kid 1979': 25,
#  'ponyo 2008': 26,
#  'brave 2012': 27,
#  'whisper of the heart 1995': 28,
#  'the girl who played with fire 2009': 29,
#  'reckless 1984': 30,
#  'ive loved you so long 2008': 31,
#  'lovely molly 2012': 32,
#  'now_ voyager 1942': 33,
#  'covert action 1978': 34,
#  'kick-ass 2010': 35,
#  'cinderella 2015': 36,
#  'in the name of the king 2 two worlds 2011': 37,
#  'viva riva 2010': 38,
#  'yellowbrickroad 2010': 39,
#  'nocturna 2007': 40,
#  'madame curie 1943': 41,
#  'the spectacular now 2013': 42,
#  'spider-man 2002': 43,
#  'trust 1990': 44,
#  'inception 2010': 45,
#  'testament of orpheus 1960': 46,
#  'tracers 2015': 47,
#  'the avengers 2012': 48,
#  'harry potter and the chamber of secrets 2002': 49,
#  'drowning by numbers 1988': 50,
#  'the other woman 2014': 51,
#  'the dark knight 2008': 52,
#  'harry potter and the philosophers stone 2001': 53,
#  'robin hood 2010': 54,
#  'the fifth element 1997': 55,
#  'thoughtcrimes 2003': 56,
#  'the matrix 1999': 57,
#  'the bourne supremacy 2004': 58,
#  'batman begins 2005': 59,
#  'x_ y and zee 1972': 60,
#  'huddersfield 2007': 61,
#  'the princess diaries 2 royal engagement 2004': 62,
#  'make way for tomorrow 1937': 63,
#  'bad fucking 2013': 64,
#  'games 1967': 65,
#  'rebel without a cause 1955': 66,
#  'a big hand for the little lady 1966': 67,
#  'dream with the fishes 1997': 68,
#  'rat pfink a boo boo 1966': 69,
#  'wrong turn 4 bloody beginnings 2011': 70,
#  'the lord of the rings the fellowship of the ring 2001': 71,
#  'fury 2014': 72,
#  'just like heaven 2005': 73,
#  'total recall 1990': 74,
#  'harry potter and the prisoner of azkaban 2004': 75,
#  'dream wife 1953': 76,
#  'aka tommy chong 2006': 77,
#  'the act in question 1993': 78,
#  'sal_ or the 120 days of sodom 1975': 79,
#  'spirited away 2001': 80,
#  'dreaming of joseph lees 1999': 81,
#  'after five in the forest primeval 1995': 82,
#  'the sea hawk 1940': 83,
#  'tangled 2010': 84,
#  'rabbit  la berlin 2009': 85,
#  'a deeper shade of blue 2011': 86,
#  'inglourious basterds 2009': 87,
#  'a christmas tale 2008': 88,
#  'the incredibles 2004': 89,
#  'cactus flower 1969': 90,
#  'fingers at the window 1942': 91,
#  'the man who knew too much 1956': 92,
#  'union pacific 1939': 93,
#  'treasure planet 2002': 94,
#  'kiras reason a love story 2001': 95,
#  'rudo  cursi 2008': 96,
#  'murder 1930': 97,
#  'all of me 1984': 98,
#  'trails 1978': 99,
#  'starman 1984': 100,
#  'the great waldo pepper 1975': 101,
#  'ray harryhausen special effects titan 2011': 102,
#  'the girl 2012': 103,
#  'they bite 1996': 104,
#  'harry potter and the half-blood prince 2009': 105,
#  'the boys from fengkuei 1983': 106,
#  'independence day 1996': 107,
#  'odd man out 1947': 108,
#  'lonesome 1928': 109,
#  'pirates of the caribbean dead mans chest 2006': 110,
#  'die hard 1988': 111,
#  'once upon a time in shanghai 2014': 112,
#  'the green mile 1999': 113,
#  'the buccaneer 1938': 114,
#  'solino 2002': 115,
#  'goodfellas 1990': 116,
#  'the dark crystal 1982': 117,
#  'moby dick 1956': 118,
#  'interkosmos 2006': 119,
#  'harry potter and the order of the phoenix 2007': 120,
#  'harry potter and the goblet of fire 2005': 121,
#  'shadow of the vampire 2000': 122,
#  'pulp fiction 1994': 123,
#  'nymphomaniac vol. ii 2013': 124,
#  'the adventures of tartu 1943': 125,
#  'gaslight 1940': 126,
#  'desperately seeking susan 1985': 127,
#  'ong-bak the thai warrior 2003': 128,
#  'dr. no 1962': 129,
#  'people like us 2012': 130,
#  'goodbye_ dragon inn 2003': 131,
#  'the damned 1969': 132,
#  'up 2009': 133,
#  'the twelve tasks of asterix 1976': 134,
#  'clean and sober 1988': 135,
#  'stalag 17 1953': 136,
#  'cabin fever patient zero 2014': 137,
#  'the lord of the rings the two towers 2002': 138,
#  'the vikings 1958': 139,
#  'forest 2003': 140,
#  'bernard and doris 2006': 141,
#  'lock_ stock and two smoking barrels 1998': 142,
#  'bon cop bad cop 2006': 143,
#  'welcome to the roses 2003': 144,
#  'right on_ man 1980': 145,
#  'the greatest show on earth 1952': 146,
#  'the man from snowy river 1982': 147,
#  'e.t. the extra-terrestrial 1982': 148,
#  'twixt 2011': 149,
#  'so much water 2013': 150,
#  'supermanbatman apocalypse 2010': 151,
#  'titanic town 1998': 152,
#  'detention of the dead 2012': 153,
#  'coming home 2014': 154,
#  'blondie on a budget 1940': 155,
#  'inferno 1980': 156,
#  '1981 2009': 157,
#  'how to train your dragon 2010': 158,
#  'black white  gray a portrait of sam wagstaff and robert mapplethorpe 2007': 159,
#  'they made me a fugitive 1947': 160,
#  'the minion 1998': 161,
#  'the house of the devil 2009': 162,
#  'numb 2007': 163,
#  'the milky way 2007': 164,
#  'kes 1969': 165,
#  'dying at grace 2003': 166,
#  'vive lamour 1994': 167,
#  'the god who wasnt there 2005': 168,
#  'the little mermaid 1989': 169,
#  'oceans eleven 2001': 170,
#  'one flew over the cuckoos nest 1975': 171,
#  'the mask 1994': 172,
#  'the emperors candlesticks 1937': 173,
#  'the blue angel 1930': 174,
#  'big daddy 1999': 175,
#  'the man who couldnt say no 1975': 176,
#  'shutter island 2010': 177,
#  'boiling point 1990': 178,
#  'men and women 1964': 179,
#  'love in the time of cholera 2007': 180,
#  'jarhead 2 field of fire 2014': 181,
#  'the lord of the rings 1978': 182,
#  'lincoln 2012': 183,
#  'operation mad ball 1957': 184,
#  'men with guns 1997': 185,
#  'spider-man 2 2004': 186,
#  'dancing in the rain 1961': 187,
#  'donner pass 2012': 188,
#  'about alex 2014': 189,
#  'ghostbusters 1984': 190,
#  'half a loaf of kung fu 1978': 191,
#  'anthony adverse 1936': 192,
#  'my neighbor totoro 1988': 193,
#  'gladiator 2000': 194,
#  'tales from earthsea 2006': 195,
#  'before sunset 2004': 196,
#  'whiplash 2014': 197,
#  'the marriage of maria braun 1979': 198,
#  'louis theroux the most hated family in america 2007': 199,
#  'the snow woman 1968': 200,
#  'indictment the mcmartin trial 1995': 201,
#  'fight for your right revisited 2011': 202,
#  'back to the future 1985': 203,
#  'apollo 13 1995': 204,
#  'toy story 3 2010': 205,
#  'walle 2008': 206,
#  'mad max 2 the road warrior 1981': 207,
#  'the family friend 2006': 208,
#  'leave her to heaven 1945': 209,
#  'crackerjack 2002': 210,
#  'geronimo an american legend 1993': 211,
#  'craig ferguson im here to help 2013': 212,
#  'one crazy summer 1986': 213,
#  'the mummy 1999': 214,
#  'the music lovers 1970': 215,
#  'dumbo 1941': 216,
#  'gone girl 2014': 217,
#  'the way to the stars 1945': 218,
#  'swoon 1992': 219,
#  'oranges 2004': 220,
#  'snow white and the seven dwarfs 1937': 221,
#  'fight club 1999': 222,
#  'le grand soir 2012': 223,
#  'vertigo 1958': 224,
#  'stonehearst asylum 2014': 225,
#  'stories we tell 2012': 226,
#  'aliens 1986': 227,
#  'the shawshank redemption 1994': 228,
#  'whistling in brooklyn 1943': 229,
#  'suraj ka satvan ghoda 1993': 230,
#  'a single man 2009': 231,
#  'brotherhood of the wolf 2001': 232,
#  'ninja scroll 1993': 233,
#  'dirty harry 1971': 234,
#  'indiana jones and the last crusade 1989': 235,
#  'men in black 1997': 236,
#  'the odd couple 1968': 237,
#  'from russia with love 1963': 238,
#  'europa europa 1990': 239,
#  'the hobbit the desolation of smaug 2013': 240,
#  'caf de flore 2011': 241,
#  'bird 1988': 242,
#  'i hired a contract killer 1990': 243,
#  'patriot games 1992': 244,
#  'coraline 2009': 245,
#  'inside man 2006': 246,
#  'bartok the magnificent 1999': 247,
#  'eight deadly shots 1972': 248,
#  'faster 2010': 249,
#  'the incredible hulk returns 1988': 250,
#  'the nautical chart 2007': 251,
#  'despicable me 2 2013': 252,
#  'malice in wonderland 2009': 253,
#  'men in black ii 2002': 254,
#  'love crime 2010': 255,
#  'the journey 1959': 256,
#  'grease 1978': 257,
#  'my summer of love 2004': 258,
#  'scooby-doo the mystery begins 2009': 259,
#  'red garters 1954': 260,
#  'contract killer 1998': 261,
#  'alien 1979': 262,
#  'the constant gardener 2005': 263,
#  'slingshot hip hop 2008': 264,
#  'freakonomics 2010': 265,
#  'the amazing spider-man 2012': 266,
#  'jenny 1936': 267,
#  'thor the dark world 2013': 268,
#  'killer 1994': 269,
#  'pirates of the caribbean at worlds end 2007': 270,
#  'medea 1969': 271,
#  'out in the dark 2012': 272,
#  'after office hours 1935': 273,
#  'no way home 1996': 274,
#  'cadillac records 2008': 275,
#  'a tale of two sisters 2003': 276,
#  'samurai iii duel at ganryu island 1956': 277,
#  'with every heartbeat 2011': 278,
#  'terminator 2 judgment day 1991': 279,
#  'x-men days of future past 2014': 280,
#  'ulak 2008': 281,
#  'the imitation game 2014': 282,
#  'the crying game 1992': 283,
#  'what doesnt kill you 2008': 284,
#  'toy story 1995': 285,
#  'ping pong summer 2014': 286,
#  'happiness is in the field 1995': 287,
#  'all the presidents men 1976': 288,
#  'here comes the boom 2012': 289,
#  'ludwig 1972': 290,
#  'the spongebob movie sponge out of water 2015': 291,
#  'friday the 13th 1980': 292,
#  'eight below 2006': 293,
#  'an innocent affair 1948': 294,
#  'the jungle book 1967': 295,
#  'kikis delivery service 1989': 296,
#  'romper stomper 1992': 297,
#  'the screaming skull 1958': 298,
#  'confess 2005': 299,
#  'godzilla vs. megaguirus 2000': 300,
#  'yumeji 1991': 301,
#  'the terminator 1984': 302,
#  'the silent scream 1979': 303,
#  'the artist 2011': 304,
#  'the carriers are waiting 1999': 305,
#  'maleficent 2014': 306,
#  'in the company of men 1997': 307,
#  'the last american virgin 1982': 308,
#  'eves bayou 1997': 309,
#  'cloud atlas 2012': 310,
#  'commando 1985': 311,
#  'backflash 2002': 312,
#  'philomena 2013': 313,
#  'angel in my pocket 1969': 314,
#  'the lone ranger 1956': 315,
#  'tangled ever after 2012': 316,
#  'the godfather 1972': 317,
#  'castle in the sky 1986': 318,
#  'iron man 2 2010': 319,
#  'titanic 1997': 320,
#  'happy 2011': 321,
#  'gattaca 1997': 322,
#  'cloudy with a chance of meatballs 2 2013': 323,
#  'charlottes web 2 wilburs great adventure 2003': 324,
#  'million dollar baby 2004': 325,
#  'how to train your dragon 2 2014': 326,
#  'viy 1967': 327,
#  'before the rain 1994': 328,
#  'fire on the mountain 1996': 329,
#  'the brood 1979': 330,
#  'predator 1987': 331,
#  'of mice and men 1939': 332,
#  'suspect 1987': 333,
#  'a prairie home companion 2006': 334,
#  'mickey_ donald_ goofy the three musketeers 2004': 335,
#  'the lion king 1 2004': 336,
#  'a womans face 1941': 337,
#  'sweet sweetbacks baadasssss song 1971': 338,
#  'hairspray 2007': 339,
#  'centennial 1978': 340,
#  'wanderlust 2012': 341,
#  'normal adolescent behavior 2007': 342,
#  'broadway melody of 1940 1940': 343,
#  'le week-end 2013': 344,
#  'piranhaconda 2012': 345,
#  'undertow 2004': 346,
#  'run_ man_ run 1968': 347,
#  'red dog 2011': 348,
#  'demonic toys 1992': 349,
#  'dr. jekyll and mr. hyde 1941': 350,
#  'the gods must be crazy 1980': 351,
#  'the heiress 1949': 352,
#  'ovosodo 1997': 353,
#  'jason becker not dead yet 2012': 354,
#  'suspect zero 2004': 355,
#  'dawn of the planet of the apes 2014': 356,
#  'tenebre 1982': 357,
#  'post tenebras lux 2012': 358,
#  'three strangers 1946': 359,
#  'lockout 2012': 360,
#  'the princess diaries 2001': 361,
#  'no mercy 1986': 362,
#  'the last days 1998': 363,
#  'the white stripes under great white northern lights 2009': 364,
#  'temptress moon 1996': 365,
#  'eureka 2000': 366,
#  'tropical malady 2005': 367,
#  'the fountain 2006': 368,
#  'guardians of the galaxy 2014': 369,
#  'akira 1988': 370,
#  'selma 2014': 371,
#  'the cheat 1915': 372,
#  'the story of maths 2008': 373,
#  'the return 2003': 374,
#  'chinese odyssey 2002 2002': 375,
#  'soulless 2012': 376,
#  'the asphalt jungle 1950': 377,
#  'kaboom 2010': 378,
#  'john wick 2014': 379,
#  'how to get ahead in advertising 1989': 380,
#  'rosenstrasse 2003': 381,
#  'a moment to remember 2004': 382,
#  'the secret garden 1993': 383,
#  'la soufrire 1977': 384,
#  'metal a headbangers journey 2005': 385,
#  'judgment at nuremberg 1961': 386,
#  'beyond the border 2011': 387,
#  'cheeky 2000': 388,
#  'moonrise kingdom 2012': 389,
#  'the plague dogs 1982': 390,
#  'im all right jack 1959': 391,
#  'breezy 1973': 392,
#  'at the circus 1939': 393,
#  'd.l. hughley reset 2012': 394,
#  'blow-up 1966': 395,
#  'star wars episode iii - revenge of the sith 2005': 396,
#  'love and bullets 1979': 397,
#  'enter nowhere 2011': 398,
#  'the perfect world of kai 2007': 399,
#  'callas forever 2002': 400,
#  'sgt. bilko 1996': 401,
#  'this film is not yet rated 2006': 402,
#  'symmetry 2003': 403,
#  'reservoir dogs 1992': 404,
#  'cover-up 1991': 405,
#  'desire 2011': 406,
#  'fort apache_ the bronx 1981': 407,
#  'stuck between stations 2011': 408,
#  'time freak 2011': 409,
#  'the big bang 2011': 410,
#  'a special day 1977': 411,
#  'look_ up in the sky the amazing story of superman 2006': 412,
#  'fires on the plain 1959': 413,
#  'let me in 2010': 414,
#  'master and commander the far side of the world 2003': 415,
#  'the secret life of bees 2008': 416,
#  'naked weapon 2002': 417,
#  'the hobbit an unexpected journey 2012': 418,
#  'the teahouse of the august moon 1956': 419,
#  'kiss the bride 2007': 420,
#  'zaat 1971': 421,
#  '8mm 2 2005': 422,
#  'nobody else but you 2011': 423,
#  'midnight express 1978': 424,
#  'chicago 2002': 425,
#  'the manchurian candidate 2004': 426,
#  'prisoners 2013': 427,
#  'and now my love 1974': 428,
#  'three quarter moon 2011': 429,
#  'crows zero 2007': 430,
#  'poison 1991': 431,
#  'mutant action 1993': 432,
#  'howls moving castle 2004': 433,
#  'snakehead terror 2004': 434,
#  'man for a day 2012': 435,
#  'pride 2014': 436,
#  'battle in seattle 2007': 437,
#  'october baby 2011': 438,
#  'return of the secaucus seven 1980': 439,
#  'big hero 6 2014': 440,
#  'saving private ryan 1998': 441,
#  'incendies 2010': 442,
#  'the boy in the striped pyjamas 2008': 443,
#  'ai weiwei never sorry 2012': 444,
#  'the paper 1994': 445,
#  'the kid 1921': 446,
#  'legends of the fall 1994': 447,
#  'lust for life 1956': 448,
#  'the mahabharata 1989': 449,
#  'zero effect 1998': 450,
#  'loaded 1996': 451,
#  'citizenfour 2014': 452,
#  'edwin boyd citizen gangster 2011': 453,
#  'gravity 2013': 454,
#  'duck soup 1933': 455,
#  'forrest gump 1994': 456,
#  'extraterrestrial 2014': 457,
#  'backdraft 1991': 458,
#  'the taking of power by louis xiv 1966': 459,
#  'holiday wishes 2006': 460,
#  'big fish 2003': 461,
#  'bloody new year 1987': 462,
#  'the fly 1958': 463,
#  'love affair 1939': 464,
#  'the ice house 1997': 465,
#  'love_ wedding_ marriage 2011': 466,
#  'charley varrick 1973': 467,
#  'lovers of the arctic circle 1998': 468,
#  'land of silence and darkness 1971': 469,
#  'kurt cobain about a son 2006': 470,
#  'my family 1995': 471,
#  'dumb and dumber 1994': 472,
#  'stuart little 3 call of the wild 2005': 473,
#  'the stendhal syndrome 1996': 474,
#  'toy story 2 1999': 475,
#  'seven samurai 1954': 476,
#  'dragon hunter 2008': 477,
#  'bennys video 1993': 478,
#  'shrek 2 2004': 479,
#  'diary of a wimpy kid rodrick rules 2011': 480,
#  'the last waltz 1978': 481,
#  'but not for me 1959': 482,
#  'crazed fruit 1956': 483,
#  'burlesque 2010': 484,
#  'border feud 1947': 485,
#  'sin city 2005': 486,
#  'experimenter 2015': 487,
#  'for no good reason 2012': 488,
#  'nickelodeon 1976': 489,
#  'woman in love 2011': 490,
#  'dial m for murder 1954': 491,
#  'underworld 1996': 492,
#  'dark command 1940': 493,
#  'scarface 1983': 494,
#  'city of women 1980': 495,
#  'the connection 2014': 496,
#  'el topo 1970': 497,
#  'lone wolf and cub sword of vengeance 1972': 498,
#  'the baby-sitters club 1995': 499,
#  'kung fu hustle 2004': 500,
#  'helsinki napoli - all night long 1987': 501,
#  'kivenpyrittjn kyl 1995': 502,
#  'the sea is watching 2002': 503,
#  'a season for miracles 1999': 504,
#  'the winning of barbara worth 1926': 505,
#  'pirates of the caribbean on stranger tides 2011': 506,
#  'city slickers ii the legend of curlys gold 1994': 507,
#  'soap girl 2002': 508,
#  'louis cyr  the strongest man in the world 2013': 509,
#  'sweethearts 1938': 510,
#  'senso 1954': 511,
#  'trucker 2008': 512,
#  'risky business 1983': 513,
#  'casino royale 2006': 514,
#  'hope springs 2003': 515,
#  'monsters_ inc. 2001': 516,
#  'p.s. 2004': 517,
#  'barneys version 2010': 518,
#  'a short film about love 1988': 519,
#  'the kids are all right 2010': 520,
#  'the thin blue line 1988': 521,
#  'the racket 1951': 522,
#  'from up on poppy hill 2011': 523,
#  'resident evil apocalypse 2004': 524,
#  'the secret world of arrietty 2010': 525,
#  'the maltese falcon 1941': 526,
#  'the spy who came in from the cold 1965': 527,
#  'first strike 1996': 528,
#  'house of sand and fog 2003': 529,
#  'boogie 2009': 530,
#  'alien nation 1988': 531,
#  'waist deep 2006': 532,
#  'cherry 2011': 533,
#  'matinee 1993': 534,
#  'bloomington 2010': 535,
#  'the tracey fragments 2007': 536,
#  'the doll squad 1973': 537,
#  'national lampoons cattle call 2006': 538,
#  'iron man 3 2013': 539,
#  'the wilby conspiracy 1975': 540,
#  'fast five 2011': 541,
#  'in the city 2003': 542,
#  'julias eyes 2010': 543,
#  'bionicle the legend reborn 2009': 544,
#  'the ear 1970': 545,
#  'the hunchback of notre dame 1996': 546,
#  'the way of the gun 2000': 547,
#  'steamboat bill_ jr. 1928': 548,
#  'the six million dollar man 1973': 549,
#  'despicable me 2010': 550,
#  'madhouse 1974': 551,
#  'the inhabited island 2 rebellion 2009': 552,
#  'the grapes of wrath 1940': 553,
#  'pocahontas ii journey to a new world 1998': 554,
#  'cinderella 1950': 555,
#  'the thompsons 2012': 556,
#  'tapia 2013': 557,
#  'bulworth 1998': 558,
#  'the preachers wife 1996': 559,
#  'beetlejuice 1988': 560,
#  'kill me now 2012': 561,
#  'trouble in mind 1985': 562,
#  'climates 2006': 563,
#  'dylan moran what it is 2009': 564,
#  'the great debaters 2007': 565,
#  'be cool 2005': 566,
#  'the cat returns 2002': 567,
#  'an education 2009': 568,
#  'the bang bang club 2010': 569,
#  'rainy dog 1997': 570,
#  'trailer park boys dont legalize it 2014': 571,
#  'the tale of sweeney todd 1998': 572,
#  'the dreamers 2003': 573,
#  'crash 2004': 574,
#  'lettera amorosa 1995': 575,
#  'two mules for sister sara 1970': 576,
#  'barry lyndon 1975': 577,
#  'ace of aces 1982': 578,
#  'winters bone 2010': 579,
#  'sonic outlaws 1995': 580,
#  'hansel  gretel 2007': 581,
#  'harry potter and the deathly hallows part 2 2011': 582,
#  'man in the wilderness 1971': 583,
#  'the giant mechanical man 2012': 584,
#  'into the woods 2014': 585,
#  'a turtles tale 2 sammys escape from paradise 2012': 586,
#  'tommy boy 1995': 587,
#  'rage of honor 1987': 588,
#  'never too young to die 1986': 589,
#  'born rich 2003': 590,
#  'katzelmacher 1969': 591,
#  'hercules and the circle of fire 1994': 592,
#  'buffalo 66 1998': 593,
#  'friends with kids 2011': 594,
#  'jean-luc cinema godard 2009': 595,
#  'shopgirl 2005': 596,
#  'the rape of europa 2006': 597,
#  'casey jones 2011': 598,
#  'chasing sleep 2000': 599,
#  'moral tales_ filmic issues 2006': 600,
#  'all about lily chou-chou 2001': 601,
#  'the awful truth 1937': 602,
#  'hard boiled 1992': 603,
#  'uncounted 2008': 604,
#  'ruby sparks 2012': 605,
#  '2001 a space odyssey 1968': 606,
#  'madhouse 2004': 607,
#  'big trouble 1986': 608,
#  'quantum of solace 2008': 609,
#  'a bridge too far 1977': 610,
#  'hondo 1953': 611,
#  'the black cauldron 1985': 612,
#  'the wild blue yonder 2005': 613,
#  'prime 2005': 614,
#  'airplane 1980': 615,
#  'little odessa 1994': 616,
#  'fargo 1996': 617,
#  'erkan  stefan 3 2005': 618,
#  'the details 2012': 619,
#  '12 2007': 620,
#  'the deer hunter 1978': 621,
#  'the philadelphia story 1940': 622,
#  'kiss me deadly 1955': 623,
#  'the story of temple drake 1933': 624,
#  'street thief 2006': 625,
#  'above the rim 1994': 626,
#  'loudquietloud a film about the pixies 2006': 627,
#  'may 18 2007': 628,
#  'the prodigal 1955': 629,
#  'the westerner 1940': 630,
#  'family resemblances 1996': 631,
#  'endangered species 2003': 632,
#  'blank check 1994': 633,
#  'homevideo 2011': 634,
#  'chicken run 2000': 635,
#  'shoulder arms 1918': 636,
#  'remember my name 1978': 637,
#  'the wonders 2014': 638,
#  'the killer 1989': 639,
#  'the manxman 1929': 640,
#  'the dark corner 1946': 641,
#  ' propos de nice 1930': 642,
#  'the homesman 2014': 643,
#  'man in the saddle 1951': 644,
#  'must have been love 2012': 645,
#  'district b13 2004': 646,
#  'once upon a honeymoon 1942': 647,
#  'the thin blue lie 2000': 648,
#  'leclisse 1962': 649,
#  'gotti 1996': 650,
#  'richard iii 1995': 651,
#  'rob roy 1995': 652,
#  'hachi a dogs tale 2009': 653,
#  'eyes without a face 1960': 654,
#  'ratatouille 2007': 655,
#  'jerry seinfeld im telling you for the last time 1998': 656,
#  'the incredible hulk 2008': 657,
#  'the way way back 2013': 658,
#  'nausica of the valley of the wind 1984': 659,
#  'look whos talking 1989': 660,
#  'the lodger 1944': 661,
#  'ida 2013': 662,
#  'a free soul 1931': 663,
#  'most 2003': 664,
#  'true lies 1994': 665,
#  'forgetting sarah marshall 2008': 666,
#  'deal of the century 1983': 667,
#  'the identical 2014': 668,
#  'the time that remains 2009': 669,
#  'american pie 2 2001': 670,
#  'sunrise a song of two humans 1927': 671,
#  'man - woman wanted 1973': 672,
#  'my life in ruins 2009': 673,
#  'thor 2011': 674,
#  'lola 1981': 675,
#  'here comes the groom 1951': 676,
#  'defiance 2008': 677,
#  'nightcrawler 2014': 678,
#  'my sisters keeper 2009': 679,
#  'bruce almighty 2003': 680,
#  'black christmas 1974': 681,
#  'yes man 2008': 682,
#  'life is sweet 1990': 683,
#  'the green 2011': 684,
#  'the princess bride 1987': 685,
#  'star wars episode i - the phantom menace 1999': 686,
#  'men without women 1930': 687,
#  'secrets  lies 1996': 688,
#  'youre a good man_ charlie brown 1985': 689,
#  'constantine 2005': 690,
#  'ivans childhood 1962': 691,
#  'how the west was won 1962': 692,
#  'vitus 2006': 693,
#  'fire_ ice  canned beer 2002': 694,
#  'project moon base 1953': 695,
#  'imitation of life 1959': 696,
#  'young detective dee rise of the sea dragon 2013': 697,
#  'another country 1984': 698,
#  'fuck you goethe 2013': 699,
#  'the swimming pool 1969': 700,
#  'phantom 2013': 701,
#  'the last battle 1983': 702,
#  'the mudlark 1950': 703,
#  'escape from the planet of the apes 1971': 704,
#  'countdown to zero 2010': 705,
#  'the scent of green papaya 1993': 706,
#  'enough said 2013': 707,
#  'the lawless 1950': 708,
#  'la haine 1995': 709,
#  'the frozen north 1922': 710,
#  'the cat o nine tails 1971': 711,
#  'casanova 2005': 712,
#  'when marnie was there 2014': 713,
#  'to be takei 2014': 714,
#  'man in the middle 1963': 715,
#  'kings game 2004': 716,
#  'safrana or freedom of speech 1978': 717,
#  'iron man 2008': 718,
#  'riders 2002': 719,
#  'italian for beginners 2000': 720,
#  'youll never get rich 1941': 721,
#  'romeo must die 2000': 722,
#  'mysterious skin 2004': 723,
#  'rosewater 2014': 724,
#  'dillinger 1945': 725,
#  'diary of a country priest 1951': 726,
#  'captain america the winter soldier 2014': 727,
#  'fanny  alexander 1982': 728,
#  'blubberella 2011': 729,
#  'oedipus rex 1967': 730,
#  'i vitelloni 1953': 731,
#  'amazing grace and chuck 1987': 732,
#  'the wolf of wall street 2013': 733,
#  'the inkwell 1994': 734,
#  'darkman ii the return of durant 1995': 735,
#  'my kingdom 2011': 736,
#  'the queen of versailles 2012': 737,
#  'oliver twist 1999': 738,
#  'jim jefferies i swear to god 2009': 739,
#  'amadeus 1984': 740,
#  'those magnificent men in their flying machines or how i flew from london to paris in 25 hours 11 minutes 1965': 741,
#  'buena vista social club 1999': 742,
#  'running out of time 1999': 743,
#  'the outlaw josey wales 1976': 744,
#  'the virgin suicides 1999': 745,
#  'wild target 2010': 746,
#  'the good heart 2009': 747,
#  'passenger 57 1992': 748,
#  'it had to be you 2000': 749,
#  'human highway 1982': 750,
#  'bad dreams 1988': 751,
#  'sister 2012': 752,
#  'my louisiana sky 2001': 753,
#  'strange invaders 2002': 754,
#  'troy 2004': 755,
#  'little white lies 2010': 756,
#  'when night is falling 1995': 757,
#  'x the man with the x-ray eyes 1963': 758,
#  'steel magnolias 1989': 759,
#  'snake and crane arts of shaolin 1978': 760,
#  'the tales of hoffmann 1951': 761,
#  'happy ever afters 2009': 762,
#  '200 mph 2011': 763,
#  'scissere 1982': 764,
#  'street fight 2005': 765,
#  'the dancing hawk 1978': 766,
#  'a good marriage 2014': 767,
#  '25th hour 2002': 768,
#  'equilibrium 2002': 769,
#  'the end of the affair 1999': 770,
#  'stage fright 1950': 771,
#  'hurt 2009': 772,
#  'the great magician 2011': 773,
#  'pinocchio 1940': 774,
#  'full moon high 1981': 775,
#  'penthouse 1933': 776,
#  'mirrormask 2005': 777,
#  'virtuality 2009': 778,
#  'monsieur  hulots holiday 1953': 779,
#  'shadows in paradise 1986': 780,
#  'rome_ open city 1945': 781,
#  'murder by numbers 2002': 782,
#  'headhunters 2011': 783,
#  'the haunting in connecticut 2009': 784,
#  'brothers 2009': 785,
#  'the garden of eden 2008': 786,
#  'bolt 2008': 787,
#  'spider-man 3 2007': 788,
#  'the brinks job 1978': 789,
#  'peter pan 1953': 790,
#  'sleeping beauty 1959': 791,
#  'doing time on maple drive 1992': 792,
#  'up in the air 2009': 793,
#  'the referee 2013': 794,
#  'elizabeth i 2005': 795,
#  'the fuller brush girl 1950': 796,
#  'the man who could cheat death 1959': 797,
#  'shrek forever after 2010': 798,
#  'weeds 1987': 799,
#  'the matrix revolutions 2003': 800,
#  'the wave 2008': 801,
#  'chicken little 2005': 802,
#  'the cross of lorraine 1943': 803,
#  'loving 1970': 804,
#  'the matrix reloaded 2003': 805,
#  'owning mahowny 2003': 806,
#  'american gangster 2007': 807,
#  'chillers 1987': 808,
#  'when time ran out... 1980': 809,
#  'down to the bone 2004': 810,
#  'the winning season 2009': 811,
#  'henry v 1989': 812,
#  'summer of 42 1971': 813,
#  'likainen pommi 2011': 814,
#  'schooled the price of college sports 2013': 815,
#  'fox and his friends 1975': 816,
#  'the clique 2008': 817,
#  'dolans cadillac 2009': 818,
#  'the willow tree 2005': 819,
#  'when brendan met trudy 2000': 820,
#  'belles on their toes 1952': 821,
#  'a christmas carol 1938': 822,
#  'ice age the meltdown 2006': 823,
#  'scaramouche 1952': 824,
#  'it rains in my village 1968': 825,
#  'striking range 2006': 826,
#  'birthday girl 2001': 827,
#  'dementia 1955': 828,
#  'frosty the snowman 1969': 829,
#  'far from the madding crowd 1967': 830,
#  'playtime 1967': 831,
#  'the whales of august 1987': 832,
#  'holly 2006': 833,
#  'bronson 2008': 834,
#  'young winston 1972': 835,
#  'out california way 1946': 836,
#  'i know what i saw 2009': 837,
#  'the young lions 1958': 838,
#  'arranged 2007': 839,
#  'seventh son 2014': 840,
#  'the i inside 2004': 841,
#  'my flesh and blood 2003': 842,
#  'the front 2010': 843,
#  'adventures of arsene lupin 2004': 844,
#  'lured 1947': 845,
#  'taken 2008': 846,
#  'family united 2013': 847,
#  'the science of sleep 2006': 848,
#  'all about my mother 1999': 849,
#  'patrick 2013': 850,
#  'penguins of madagascar 2014': 851,
#  'cleanflix 2010': 852,
#  'witness for the prosecution 1957': 853,
#  'no mercy 2010': 854,
#  'better things 2008': 855,
#  'snakes and earrings 2008': 856,
#  'the foul king 2000': 857,
#  'stage door 1937': 858,
#  'true grit 1969': 859,
#  'anita 2013': 860,
#  'the trouble with harry 1955': 861,
#  'the 6th day 2000': 862,
#  'carry on behind 1975': 863,
#  'it follows 2015': 864,
#  'conan the barbarian 1982': 865,
#  'kevin hart seriously funny 2010': 866,
#  'michael jackson life of a superstar 2008': 867,
#  'pk 2014': 868,
#  'phoenix 2014': 869,
#  'target 1995': 870,
#  'the childrens hour 1961': 871,
#  'the dark knight rises 2012': 872,
#  'car bpnus 2001': 873,
#  'the care bears adventure in wonderland 1987': 874,
#  'wild china 2008': 875,
#  'runaway 2009': 876,
#  'the unbelievable truth 1989': 877,
#  'in the shadow of the moon 2007': 878,
#  'kedma 2002': 879,
#  'an american tail 1986': 880,
#  'monty python and the holy grail 1975': 881,
#  'any questions for ben 2012': 882,
#  'valley uprising 2014': 883,
#  'a golden christmas 3 2013': 884,
#  'one hundred and one dalmatians 1961': 885,
#  'dynamite 1929': 886,
#  'willy wonka  the chocolate factory 1971': 887,
#  'primary colors 1998': 888,
#  'the five senses 1999': 889,
#  'bloodstone subspecies ii 1993': 890,
#  'kings and queen 2004': 891,
#  'special bulletin 1983': 892,
#  'dark angel the ascent 1994': 893,
#  'the tree 2014': 894,
#  'bushwhacked 1995': 895,
#  'burn after reading 2008': 896,
#  'the simpsons movie 2007': 897,
#  'tomorrow at dawn 2009': 898,
#  'for the bible tells me so 2007': 899,
#  'the immortal story 1968': 900,
#  'fugly 2014': 901,
#  'an american in paris 1951': 902,
#  'swept away 1974': 903,
#  'the last king of scotland 2006': 904,
#  'first blood 1982': 905,
#  'how i killed my father 2001': 906,
#  'coherence 2013': 907,
#  'for your eyes only 1981': 908,
#  'y tu mam tambin 2001': 909,
#  'whip it 2009': 910,
#  'kill your darlings 2013': 911,
#  'letters from iwo jima 2006': 912,
#  'to kill a mockingbird 1962': 913,
#  'interstate 60 2002': 914,
#  'finding nemo 2003': 915,
#  'its alive 2008': 916,
#  'timecrimes 2007': 917,
#  'sirens 1993': 918,
#  'wattstax 1973': 919,
#  'after image 2001': 920,
#  'anastasia 1997': 921,
#  'the third part of the night 1971': 922,
#  'the damned 1947': 923,
#  'the lion king 1994': 924,
#  'bowling for columbine 2002': 925,
#  'judgment in berlin 1988': 926,
#  'private fears in public places 2006': 927,
#  'mulan 1998': 928,
#  'paris is burning 1990': 929,
#  'kingsman the secret service 2015': 930,
#  'daughter from danang 2002': 931,
#  'shirin in love 2014': 932,
#  'one hour with you 1932': 933,
#  'dramamex 2006': 934,
#  'hammett 1982': 935,
#  'charade 1963': 936,
#  'twilight of a womans soul 1913': 937,
#  'boy upside down 2014': 938,
#  'charlie chan at monte carlo 1937': 939,
#  'cellular 2004': 940,
#  'the great rock n roll swindle 1980': 941,
#  'crossed tracks 2007': 942,
#  'the land before time xii the great day of the flyers 2006': 943,
#  'blade runner 1982': 944,
#  'indiscreet 1958': 945,
#  'the flowers of war 2011': 946,
#  'these amazing shadows 2011': 947,
#  'the landlord 1970': 948,
#  'the reformer and the redhead 1950': 949,
#  'minority report 2002': 950,
#  'a room with a view 1985': 951,
#  'johnny apollo 1940': 952,
#  'fracture 2007': 953,
#  'chronos 1985': 954,
#  'fletch 1985': 955,
#  '6 days to air the making of south park 2011': 956,
#  'i spit on your grave 2010': 957,
#  'we are marshall 2006': 958,
#  'revenge of the green dragons 2014': 959,
#  'sanjuro 1962': 960,
#  'empire records 1995': 961,
#  'masti 2004': 962,
#  'its the great pumpkin_ charlie brown 1966': 963,
#  'the haunting 1963': 964,
#  'the way back 2010': 965,
#  'the lower depths 1957': 966,
#  'center stage 2000': 967,
#  'watchmen 2009': 968,
#  'will ferrell youre welcome america - a final night with george w. bush 2009': 969,
#  'spirit stallion of the cimarron 2002': 970,
#  'ashes and diamonds 1958': 971,
#  'hoop dreams 1994': 972,
#  'blackballed the bobby dukes story 2004': 973,
#  'the bench 2000': 974,
#  'pollock 2000': 975,
#  'buckskin frontier 1943': 976,
#  'harry potter and the deathly hallows part 1 2010': 977,
#  'bed and board 1970': 978,
#  'longford 2006': 979,
#  'captive women 1952': 980,
#  'repo man 1984': 981,
#  'the place promised in our early days 2004': 982,
#  'celeste  jesse forever 2012': 983,
#  'redes 1936': 984,
#  'antarctica 1983': 985,
#  'whisper 2007': 986,
#  'madadayo 1993': 987,
#  'captain phillips 2013': 988,
#  'thr3e 2006': 989,
#  'the golden dream 2013': 990,
#  'cinderella man 2005': 991,
#  'exodus 1960': 992,
#  'starsuckers 2009': 993,
#  'vice 2015': 994,
#  'hyenas 1992': 995,
#  'theres only one sun 2007': 996,
#  'the best exotic marigold hotel 2011': 997,
#  'papillon 1973': 998,
#  'princess mononoke 1997': 999,
#  ...}

# %%
# Create user-movie matrix in sparse format
user_ids = df["user_id"].astype("category").cat.codes
movie_ids = df["movie_title"].map(movie_mapping)

user_ids, movie_ids
# Out:
# (0         177977
#  1         191263
#  2         202651
#  3          70219
#  4         168645
#             ...
#  462959    211383
#  462960     14085
#  462961    195321
#  462962    148207
#  462963     76461
#  Length: 462964, dtype: int32,
#  0             0
#  1             1
#  2             2
#  3             3
#  4             4
#            ...
#  462959    10937
#  462960    11675
#  462961     2932
#  462962    14308
#  462963    18097
#  Name: movie_title, Length: 462964, dtype: int64)

# %%
# Build a sparse matrix
ratings_sparse = csr_matrix((df["rating"], (user_ids, movie_ids)))
ratings_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 462603 stored elements and shape (212294, 26548)>

# %%
# Compute item-item similarity using Cosine Similarity
movie_similarity = cosine_similarity(ratings_sparse.T, dense_output=False)  # Keeps it sparse
movie_similarity
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 846968 stored elements and shape (26548, 26548)>

# %%
# Save model as a dictionary (movie title → similarity row)
# movie_sim_dict = {movie: movie_similarity[idx].toarray().flatten() for movie, idx in movie_mapping.items()}
# movie_sim_dict

# with open(ITEM_SIMILARITY_MODEL, "wb") as f:
#     pickle.dump(movie_sim_dict, f)

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Assuming df, ratings_sparse, and movie_mapping are already defined

# Create a reverse mapping from index to movie title
reverse_movie_mapping = {idx: movie for movie, idx in movie_mapping.items()}

# Fit NearestNeighbors model directly on sparse matrix
nn_model = NearestNeighbors(metric="cosine", algorithm="auto", n_jobs=-1)
nn_model.fit(ratings_sparse.T)  # Transposed sparse matrix

# Find top-k similar movies for each movie
k = 10  # Number of neighbors
distances, indices = nn_model.kneighbors(ratings_sparse.T, n_neighbors=k)

# Create similarity dictionary with only top-k neighbors
movie_sim_dict = {}
for i, movie in enumerate(movie_mapping.keys()):
    similar_movies = {}
    for j, idx in enumerate(indices[i]):
        if idx in reverse_movie_mapping:  # Check if the index exists in our mapping
            similar_movie = reverse_movie_mapping[idx]
            similarity = 1 - distances[i][j]  # Convert distance to similarity
            similar_movies[similar_movie] = similarity
    movie_sim_dict[movie] = similar_movies

# Now movie_sim_dict contains each movie and its top-k similar movies with similarity scores

# %%
movie_sim_dict
# Out:
# {'rare exports a christmas tale 2010': {'rare exports a christmas tale 2010': np.float64(0.9999999999999999),
#   'the living idol 1957': np.float64(0.10053171088078183),
#   'eternally yours 1939': np.float64(0.09284489000865015),
#   'love the beast 2009': np.float64(0.08980174575841637),
#   'love meetings 1965': np.float64(0.08167234800792311),
#   'splinter 2008': np.float64(0.07184139660673305),
#   'just cause 1995': np.float64(0.07092850823103869),
#   'the king of escape 2009': np.float64(0.0651519950185655),
#   'satans blood 1978': np.float64(0.06482541654590579),
#   'manhattan 1979': np.float64(0.0580979275104041)},
#  'far away 2001': {'far away 2001': np.float64(0.9999999999999999),
#   'tales from the organ trade 2013': np.float64(0.14606543485462808),
#   'safe house 2012': np.float64(0.06239927229006337),
#   'lone star 1996': np.float64(0.05314835774019566),
#   'a single girl 1995': np.float64(0.04674961983623438),
#   'gasland 2010': np.float64(0.04001350683822158),
#   'colossus the forbin project 1970': np.float64(0.038448111772822036),
#   'whisper of the heart 1995': np.float64(0.012563695646205741),
#   'for ellen 2012': np.float64(0.0),
#   'mostly sunny 2012': np.float64(0.0)},
#  'the princess and the frog 2009': {'the princess and the frog 2009': np.float64(1.0),
#   'crocodile dundee in los angeles 2001': np.float64(0.05059138367725802),
#   'the affair of the necklace 2001': np.float64(0.045286552936900315),
#   'no small affair 1984': np.float64(0.03617774375582672),
#   'the sky crawlers 2008': np.float64(0.0326565977406017),
#   'italianamerican 1974': np.float64(0.031231629370926606),
#   'showtime 2002': np.float64(0.030476982934122043),
#   'peep world 2010': np.float64(0.02996774934550339),
#   'the curiosity of chance 2006': np.float64(0.0285685718570714),
#   'kestrels eye 1998': np.float64(0.02800280154040613)},
#  'soul assassin 2001': {'soul assassin 2001': np.float64(1.0),
#   'mushi-shi the movie 2006': np.float64(0.1586657656043835),
#   'love unto death 1984': np.float64(0.13029246839689124),
#   'almost you 1985': np.float64(0.09548198320525769),
#   'crazy on the outside 2010': np.float64(0.08770580193070288),
#   'dreams 1990': np.float64(0.07324020342698201),
#   'birdman of alcatraz 1962': np.float64(0.03523928943430088),
#   'the wolf of wall street 2013': np.float64(0.015392840253090956),
#   'casino royale 2006': np.float64(0.013888014515636926),
#   'harry potter and the chamber of secrets 2002': np.float64(0.009010142118036857)},
#  'civil brand 2003': {'civil brand 2003': np.float64(1.0),
#   'road_ movie 2009': np.float64(0.10455225530359846),
#   'the hyperboloid of engineer garin 1965': np.float64(0.09672388203287419),
#   'cyrus 2010': np.float64(0.09560008094143613),
#   'attack from space 1965': np.float64(0.08265581531669752),
#   'cambridge spies 2003': np.float64(0.07957438376509585),
#   'outpost black sun 2012': np.float64(0.07862136275414389),
#   'catch-22 1970': np.float64(0.07502344849205334),
#   'dandelion 2004': np.float64(0.07044699536763466),
#   'cold comfort farm 1995': np.float64(0.06824059055561504)},
#  'the lord of the rings the return of the king 2003': {'the lord of the rings the return of the king 2003': np.float64(0.9999999999999902),
#   'patty hearst 1988': np.float64(0.02910932676706346),
#   'date with an angel 1987': np.float64(0.025557148983035738),
#   'the mystery of the yellow room 2003': np.float64(0.025305348271041694),
#   'himizu 2011': np.float64(0.024794076410988963),
#   'virtual sexuality 1999': np.float64(0.02258954169212435),
#   'the return of ringo 1965': np.float64(0.02258954169212435),
#   'young at heart 1954': np.float64(0.021007847056116136),
#   'adam  steve 2006': np.float64(0.020433009266963564),
#   'tom segura completely normal 2014': np.float64(0.02024606106161564)},
#  'logans run 1976': {'logans run 1976': np.float64(0.9999999999999999),
#   'the valley 1972': np.float64(0.17026981474626568),
#   'cosmopolis 2012': np.float64(0.13438736818105856),
#   'murder over new york 1940': np.float64(0.12406456138646282),
#   'somewhere between 2012': np.float64(0.11664236870396083),
#   'children of the corn 2009': np.float64(0.08772689266130251),
#   'viva riva 2010': np.float64(0.08579859361170494),
#   'sink or swim 1990': np.float64(0.07496879999718598),
#   'soloalbum 2003': np.float64(0.07299318686018119),
#   'ponette 1996': np.float64(0.07095989113962753)},
#  'even angels eat beans 1973': {'even angels eat beans 1973': np.float64(0.9999999999999998),
#   'nadine 1987': np.float64(0.1641306230177222),
#   'green dolphin street 1947': np.float64(0.11160467099736426),
#   'predator 2 1990': np.float64(0.10786761979449289),
#   'city for conquest 1940': np.float64(0.0904977375565611),
#   'farce of the penguins 2006': np.float64(0.08937989593916762),
#   'beautiful creatures 2013': np.float64(0.08370350324802311),
#   'parisian love 1925': np.float64(0.07494732117818859),
#   'not quite hollywood 2008': np.float64(0.07409392785924696),
#   'black river 1957': np.float64(0.07239819004524883)},
#  'interstellar 2014': {'interstellar 2014': np.float64(0.9999999999999944),
#   'the crow city of angels 1996': np.float64(0.02626962170530267),
#   'alice in wonderland 1985': np.float64(0.025638910420716865),
#   'bethlehem 2013': np.float64(0.023516686608814896),
#   'tokyo 2008': np.float64(0.02224092354175211),
#   'saint john of las vegas 2009': np.float64(0.02184015335481526),
#   'moment by moment 1978': np.float64(0.021015697364242136),
#   'the blue lagoon 1980': np.float64(0.01911395735929078),
#   'switch 1991': np.float64(0.018956299648127617),
#   'the thing called love 1993': np.float64(0.018797011160403443)},
#  'star wars 1977': {'star wars 1977': np.float64(1.0),
#   'death wish 3 1985': np.float64(0.027467966994378812),
#   'black dawn 2005': np.float64(0.027467966994378812),
#   'geography club 2013': np.float64(0.02745456471644292),
#   'fame high 2012': np.float64(0.023695576442115063),
#   'coffee town 2013': np.float64(0.022886558143074498),
#   'happy campers 2001': np.float64(0.020944128482929703),
#   'love in the time of cholera 2007': np.float64(0.02073362938685075),
#   'lucky lady 1975': np.float64(0.020731862372965537),
#   'jamie and jessie are not together 2011': np.float64(0.020381190747488342)},
#  'the goonies 1985': {'the goonies 1985': np.float64(1.0),
#   'what planet are you from 2000': np.float64(0.045088293240900024),
#   'the ring 1927': np.float64(0.037947453354065575),
#   'booty call 1997': np.float64(0.03363126200798838),
#   'night shift 1982': np.float64(0.032361696955831576),
#   'abbott and costello meet captain kidd 1952': np.float64(0.03207443491040296),
#   'amer 2009': np.float64(0.029961109504457073),
#   'camilla 1994': np.float64(0.02974460728176853),
#   'lara croft tomb raider the cradle of life 2003': np.float64(0.02957942373494682),
#   '100 girls 2000': np.float64(0.02916698710651766)},
#  'lagaan once upon a time in india 2001': {'lagaan once upon a time in india 2001': np.float64(1.0),
#   'madeline 1998': np.float64(0.1264708726856737),
#   'sundome 2007': np.float64(0.08762159086766474),
#   'jewtopia 2012': np.float64(0.08204265211441175),
#   'a justified life sam peckinpah and the high country 2006': np.float64(0.08074436724332845),
#   'show boat 1951': np.float64(0.06905548757403146),
#   'unknown 2011': np.float64(0.06565211103589674),
#   'bronco billy 1980': np.float64(0.061957821080878994),
#   'baby boom 1987': np.float64(0.059254295869969886),
#   'accomplices 2010': np.float64(0.059149195047059844)},
#  'raiders of the lost ark 1981': {'raiders of the lost ark 1981': np.float64(1.0),
#   'jefferson in paris 1995': np.float64(0.037654596609815405),
#   'micki  maude 1984': np.float64(0.029584245117382668),
#   'basket case 3 1992': np.float64(0.029584245117382668),
#   'salvation boulevard 2011': np.float64(0.026776602033646513),
#   'bill maher ...but im not wrong 2010': np.float64(0.024362397457759144),
#   'soul man 1986': np.float64(0.023667396093906223),
#   'attack of the puppet people 1958': np.float64(0.023667396093906223),
#   'home fries 1998': np.float64(0.023667396093906223),
#   'third world cop 1999': np.float64(0.021300656484515512)},
#  'the offence 1973': {'the offence 1973': np.float64(1.0),
#   'free enterprise 1998': np.float64(0.14955666077105323),
#   'ring of terror 1962': np.float64(0.11168711865749104),
#   'texas carnival 1951': np.float64(0.10645227477036323),
#   'point break 1991': np.float64(0.09491579957524987),
#   'travel beyond the three seas 1957': np.float64(0.0929981109950554),
#   'the jeffrey dahmer files 2013': np.float64(0.08710071126186847),
#   'a dead calling 2006': np.float64(0.0858545710548213),
#   'marriage retreat 2011': np.float64(0.08442752589059521),
#   'teachers 1984': np.float64(0.07785972581032119)},
#  'mississippi mermaid 1969': {'mississippi mermaid 1969': np.float64(0.9999999999999999),
#   'the man who could work miracles 1936': np.float64(0.14872731984475063),
#   'the black orchid 1958': np.float64(0.11174521339154042),
#   'sleepaway camp 1983': np.float64(0.11154548988356294),
#   'the story of xinghua 1994': np.float64(0.10389829438753684),
#   'crime wave 1954': np.float64(0.09600307214746384),
#   'lone wolf and cub baby cart to hades 1972': np.float64(0.08855741891319435),
#   'make way for tomorrow 1937': np.float64(0.07236503841694475),
#   'last year at marienbad 1961': np.float64(0.052536161839682016),
#   'the incredible hulk 2008': np.float64(0.025003693445284192)},
#  'wreck-it ralph 2012': {'wreck-it ralph 2012': np.float64(1.0),
#   'iron eagle ii 1988': np.float64(0.04092084994511047),
#   'jingle all the way 1996': np.float64(0.03273667995608831),
#   'not one less 1999': np.float64(0.030763884907784034),
#   'chill factor 1999': np.float64(0.027561006050939585),
#   'magnificent warriors 1987': np.float64(0.02663720445381823),
#   'the ufo incident 1975': np.float64(0.02596801754111011),
#   'thunder bay 1953': np.float64(0.025777712474322256),
#   'never met picasso 1996': np.float64(0.025575531215694003),
#   'diebinnen 1996': np.float64(0.02455250996706626)},
#  'american beauty 1999': {'american beauty 1999': np.float64(1.0),
#   'branded 2012': np.float64(0.08193464903987024),
#   'the young and prodigious t.s. spivet 2013': np.float64(0.07580902681744794),
#   'a golden christmas 2009': np.float64(0.07496633127898333),
#   'the prophet 1968': np.float64(0.06988565578146122),
#   'dororo 2007': np.float64(0.06671011187601339),
#   'tobor the great 1954': np.float64(0.06503420275836858),
#   'hoot 2006': np.float64(0.06405126152203489),
#   'my mom is a character 2013': np.float64(0.06405126152203489),
#   'the girl next door 2004': np.float64(0.06311158328101896)},
#  'the town 2010': {'the town 2010': np.float64(1.0),
#   'the man who changed his mind 1936': np.float64(0.09495751305048006),
#   'together again 1944': np.float64(0.08459216914326873),
#   'antonio gaud 1984': np.float64(0.08282551320159759),
#   'the fountainhead 1949': np.float64(0.07016936464152279),
#   'zig zag 1970': np.float64(0.0656709103303118),
#   'bad fucking 2013': np.float64(0.059815696436484767),
#   'i see a dark stranger 1946': np.float64(0.059815696436484767),
#   'revolution 1985': np.float64(0.058277151741435884),
#   'the soldier 1982': np.float64(0.058277151741435884)},
#  'a kiss before dying 1991': {'a kiss before dying 1991': np.float64(1.0),
#   'the benchwarmers 2006': np.float64(0.15000000000000002),
#   'the milky way 2007': np.float64(0.09811049102515934),
#   'true heart 1999': np.float64(0.08928852638991136),
#   'temptation confessions of a marriage counselor 2013': np.float64(0.08090398349558903),
#   'siberia 1998': np.float64(0.05976143046671967),
#   'the last man on earth 1964': np.float64(0.051483235720080955),
#   'emperor 2012': np.float64(0.044609973674547),
#   'casino 1995': np.float64(0.036487819155789025),
#   'penguins of madagascar 2014': np.float64(0.027835560025568862)},
#  'pirates of the caribbean the curse of the black pearl 2003': {'pirates of the caribbean the curse of the black pearl 2003': np.float64(0.9999999999999986),
#   'indestructible man 1956': np.float64(0.030510359072045357),
#   'the hebrew hammer 2003': np.float64(0.02959939603048589),
#   'uro 2006': np.float64(0.02907991336763338),
#   'black moon 1934': np.float64(0.028198020926014977),
#   'the climax 1944': np.float64(0.023824587764267435),
#   'the moon-spinners 1964': np.float64(0.023263930694106705),
#   'here be dragons 2013': np.float64(0.022791783777483587),
#   'exit wounds 2001': np.float64(0.022741078967673634),
#   'jimmy and judy 2006': np.float64(0.02266252578314698)},
#  'avatar 2009': {'avatar 2009': np.float64(1.0),
#   'even cowgirls get the blues 1994': np.float64(0.04672897196261683),
#   'veijarit 2010': np.float64(0.03871541354806152),
#   'the haunting 1999': np.float64(0.03738317757009346),
#   'rent-a-cop 1987': np.float64(0.03738317757009346),
#   'random hearts 1999': np.float64(0.03343653050466977),
#   'ed 1996': np.float64(0.031104683900480157),
#   'help im a fish 2000': np.float64(0.030315168555212546),
#   'hero and the terror 1988': np.float64(0.028037383177570097),
#   'burn up 1991': np.float64(0.026851521346574203)},
#  'overnight 2003': {'overnight 2003': np.float64(1.0),
#   'cannibal ferox 1981': np.float64(0.15552315827194785),
#   'dangan runner 1996': np.float64(0.10826639239215341),
#   'out for justice 1991': np.float64(0.10482848367219177),
#   'the story of louis pasteur 1936': np.float64(0.10332916580768914),
#   'poohs grand adventure the search for christopher robin 1997': np.float64(0.10241473042780902),
#   'the mad magician 1954': np.float64(0.09923552325468055),
#   'hell ride 2008': np.float64(0.09362816758985393),
#   'breaking and entering 2011': np.float64(0.09236060987562233),
#   'estmago a gastronomic story 2007': np.float64(0.09078412990032037)},
#  'bells are ringing 1960': {'bells are ringing 1960': np.float64(1.0),
#   'body double 1984': np.float64(0.11766301973435522),
#   'man of steel 2013': np.float64(0.07677239147046122),
#   'unmade beds 1997': np.float64(0.07079923254047893),
#   'aprile 1998': np.float64(0.038177085778546616),
#   'mr. smith goes to washington 1939': np.float64(0.029403817083745176),
#   'from dusk till dawn 1996': np.float64(0.024485707447402194),
#   'wreck-it ralph 2012': np.float64(0.019558097543259656),
#   'the matrix 1999': np.float64(0.012412962881407918),
#   'walle 2008': np.float64(0.01058884925449588)},
#  'crouching tiger_ hidden dragon 2000': {'crouching tiger_ hidden dragon 2000': np.float64(1.0),
#   'the 3 worlds of gulliver 1960': np.float64(0.155270527392793),
#   'mvp most valuable primate 2000': np.float64(0.11508706752968723),
#   'witchs night out 1978': np.float64(0.10594623321618035),
#   'the black hole 1979': np.float64(0.09067003383365535),
#   'cheech  chongs the corsican brothers 1984': np.float64(0.08769643315409859),
#   'diggers 2006': np.float64(0.08137884587711597),
#   'a garfield christmas special 1987': np.float64(0.08137884587711597),
#   'love  pop 1998': np.float64(0.08013634778553225),
#   '21 ways to ruin a marriage 2013': np.float64(0.07083119367334179)},
#  'mountains of the moon 1990': {'mountains of the moon 1990': np.float64(0.9999999999999998),
#   'something real and good 2013': np.float64(0.10641760982554993),
#   'il... belpaese 1977': np.float64(0.09979166846852838),
#   'broken 2012': np.float64(0.09501428884810914),
#   'my sons 1991': np.float64(0.08366191769856035),
#   'red dawn 1984': np.float64(0.08029158646278667),
#   'ivan the terrible_ part ii the boyars plot 1958': np.float64(0.07966511457783831),
#   'the four feathers 1929': np.float64(0.07424258698676955),
#   'shoot em up 2007': np.float64(0.07027825980708813),
#   'martin 1978': np.float64(0.0654176840542744)},
#  'the sheriff and the satellite kid 1979': {'the sheriff and the satellite kid 1979': np.float64(0.9999999999999998),
#   'the kid from brooklyn 1946': np.float64(0.105657180233377),
#   'dark blue 2002': np.float64(0.10356162766686672),
#   'cornered 1945': np.float64(0.09566613377789002),
#   'silkwood 1983': np.float64(0.08908708063747484),
#   'punchline 1988': np.float64(0.07675295564533358),
#   'crackerjack 2002': np.float64(0.07370533237637089),
#   'ticker 2001': np.float64(0.06900655593423544),
#   'north country 2005': np.float64(0.06585506497446658),
#   'noise 2008': np.float64(0.058167505074711134)},
#  'ponyo 2008': {'ponyo 2008': np.float64(0.9999999999999912),
#   'urban legends final cut 2000': np.float64(0.041882451812863875),
#   'revenge 1990': np.float64(0.03894988902437768),
#   'the shadow 1994': np.float64(0.036558001090055026),
#   'vulgar 2000': np.float64(0.033505961450291055),
#   'fifty shades of grey 2015': np.float64(0.033505961450291055),
#   'wish upon a star 1996': np.float64(0.03316230147905619),
#   'silent rage 1982': np.float64(0.028731124912821815),
#   'milius 2013': np.float64(0.028442362559763734),
#   'tar 1997': np.float64(0.027878645086787168)},
#  'brave 2012': {'brave 2012': np.float64(1.0),
#   'a thin line between love and hate 1996': np.float64(0.03958165567962346),
#   'jo jo dancer_ your life is calling 1986': np.float64(0.03682125117617652),
#   'joe cocker - mad dogs  englishmen 1971': np.float64(0.03379927308202224),
#   'supernova 2000': np.float64(0.03129204637703753),
#   'the st  francisville experiment 2000': np.float64(0.03129204637703753),
#   'real men 1987': np.float64(0.03129204637703753),
#   'lost christmas 2011': np.float64(0.030357744106882856),
#   'lawnmower man 2 beyond cyberspace 1996': np.float64(0.027645027483369056),
#   'still smokin 1983': np.float64(0.027099707098915293)},
#  'whisper of the heart 1995': {'whisper of the heart 1995': np.float64(1.0),
#   'holiday wishes 2006': np.float64(0.03528786040651122),
#   'the thing called love 1993': np.float64(0.031562421859792966),
#   'mars needs moms 2011': np.float64(0.0272251753685967),
#   'q  a 1990': np.float64(0.026906741310447457),
#   'american psycho 2 all american girl 2002': np.float64(0.026465895304883413),
#   'the mummy tomb of the dragon emperor 2008': np.float64(0.02595194550082769),
#   'long time dead 2002': np.float64(0.0251759591728844),
#   'with fire and sword 1999': np.float64(0.024207272529692125),
#   'spring fever 1927': np.float64(0.02259073772978637)},
#  'the girl who played with fire 2009': {'the girl who played with fire 2009': np.float64(1.0),
#   'the show 1995': np.float64(0.11745619517236705),
#   'bachelor night 2014': np.float64(0.0883331028202744),
#   'mr. beans holiday 2007': np.float64(0.08095109602454653),
#   'my son 2006': np.float64(0.07818534205521166),
#   'from paris with love 2010': np.float64(0.06609629312639431),
#   'splinter 2008': np.float64(0.06514769960615396),
#   'the last play at shea 2010': np.float64(0.05911832179654797),
#   'jesus christ vampire hunter 2001': np.float64(0.057923889140479745),
#   'shaolin wooden men 1976': np.float64(0.057420790167274305)},
#  'reckless 1984': {'reckless 1984': np.float64(1.0),
#   'skylark 1941': np.float64(0.09980266896697776),
#   'some kind of wonderful 1987': np.float64(0.09897096555895502),
#   'the great spy chase 1964': np.float64(0.08761017349465239),
#   'muppets most wanted 2014': np.float64(0.05855505001214123),
#   'scent of a woman 1992': np.float64(0.054872948542669664),
#   'partly cloudy 2009': np.float64(0.04784797859851364),
#   'independence day 1996': np.float64(0.030599838830117077),
#   'alice in wonderland 1951': np.float64(0.022107230209039708),
#   'ratatouille 2007': np.float64(0.016649152356975172)},
#  'ive loved you so long 2008': {'ive loved you so long 2008': np.float64(0.9999999999999996),
#   'prison terminal the last days of private jack hall 2013': np.float64(0.0811295006256798),
#   'infection 2004': np.float64(0.07593428150025239),
#   'baghban 2003': np.float64(0.06640433435235937),
#   'soldier of orange 1977': np.float64(0.06440497390481659),
#   'solomon kane 2009': np.float64(0.06400819357319965),
#   'xingu 2012': np.float64(0.06331946906003538),
#   'a movie 1958': np.float64(0.06328480195146358),
#   'appropriate adult 2011': np.float64(0.061627868568703614),
#   'dark blue almost black 2006': np.float64(0.06065286324133756)},
#  'lovely molly 2012': {'lovely molly 2012': np.float64(0.9999999999999998),
#   'fools parade 1971': np.float64(0.14008982637729472),
#   'love_ wedding_ marriage 2011': np.float64(0.12658227848101267),
#   'kurt cobain about a son 2006': np.float64(0.10119468415798694),
#   'life is rosy 1987': np.float64(0.07037911332728819),
#   'miracle on 34th street 1947': np.float64(0.06983470290012417),
#   'touchback 2011': np.float64(0.06124202828995007),
#   'a star athlete 1937': np.float64(0.05457477945438183),
#   'confession 1937': np.float64(0.04939777634739961),
#   'the general 1926': np.float64(0.0454894366158034)},
#  'now_ voyager 1942': {'now_ voyager 1942': np.float64(1.0),
#   'city streets 1931': np.float64(0.08267255234538318),
#   'under the skin 1997': np.float64(0.0738724728710689),
#   'el big bang de tunguska 2008': np.float64(0.06763408340006449),
#   'dark prince the true story of dracula 2000': np.float64(0.0673966312332519),
#   'the big sleep 1978': np.float64(0.06625475303801631),
#   'comes a bright day 2012': np.float64(0.06558293617577415),
#   'in our garden 2002': np.float64(0.06501014846998099),
#   'before the revolution 1964': np.float64(0.05915566301365971),
#   'magic  bird a courtship of rivals 2010': np.float64(0.05599693145223228)},
#  'covert action 1978': {'covert action 1978': np.float64(1.0),
#   'the manxman 1929': np.float64(0.11231623250591982),
#   'dogs in space 1986': np.float64(0.10918004903242984),
#   'inuyasha the movie 2 the castle beyond the looking glass 2002': np.float64(0.09302023735874021),
#   'blue crush 2002': np.float64(0.0903149581295718),
#   'brother orchid 1940': np.float64(0.08196843693524514),
#   'the informant 2009': np.float64(0.07935633245599183),
#   'the whole ten yards 2004': np.float64(0.07808100334232682),
#   'tora tora tora 1970': np.float64(0.07717579618688186),
#   'poliwood 2009': np.float64(0.07490934432184693)},
#  'kick-ass 2010': {'kick-ass 2010': np.float64(1.0),
#   'wont anybody listen 2001': np.float64(0.139679245698352),
#   'autumn ball 2007': np.float64(0.08617168196860081),
#   'miss congeniality 2000': np.float64(0.08370912395884322),
#   'dracula 1992': np.float64(0.07255812760537106),
#   'the puzzle 2010': np.float64(0.07106959753306707),
#   'china obrien 1990': np.float64(0.06972223628115981),
#   'de nieuwe wildernis 2013': np.float64(0.06842857592356089),
#   'addicted to love 1997': np.float64(0.06409750236178802),
#   'making do the right thing 1989': np.float64(0.06198221427612127)},
#  'cinderella 2015': {'cinderella 2015': np.float64(0.9999999999999901),
#   'sheena 1984': np.float64(0.05271835819664861),
#   'slaughterhouse 1987': np.float64(0.05271835819664861),
#   'a very natural thing 1974': np.float64(0.040197371276355365),
#   'dream a little dream 1989': np.float64(0.038358239868340416),
#   'first name carmen 1983': np.float64(0.03804619787008778),
#   'a christmas carol 1997': np.float64(0.035870299349738954),
#   'north 1994': np.float64(0.03431672821159337),
#   'living with michael jackson a tonight special 2003': np.float64(0.03253847709697755),
#   'the wild blue yonder 2005': np.float64(0.03173272262392346)},
#  'in the name of the king 2 two worlds 2011': {'in the name of the king 2 two worlds 2011': np.float64(0.9999999999999999),
#   'cass timberlane 1947': np.float64(0.14485719366802963),
#   'gang related 1997': np.float64(0.1069913327322316),
#   'the open road 2009': np.float64(0.10044039219036505),
#   'sons of perdition 2010': np.float64(0.1000138917830774),
#   'michael 2011': np.float64(0.09022301368820751),
#   'top banana 1954': np.float64(0.08812102431690705),
#   'taken 2 2012': np.float64(0.06766726026615566),
#   'kuch kuch hota hai 1998': np.float64(0.0661179604907286),
#   'walk on water 2004': np.float64(0.0587473495446047)},
#  'viva riva 2010': {'viva riva 2010': np.float64(0.9999999999999998),
#   'tin men 1987': np.float64(0.15458476225748696),
#   'murder over new york 1940': np.float64(0.1257389226923863),
#   'the adventures of prince achmed 1926': np.float64(0.1257389226923863),
#   'somewhere between 2012': np.float64(0.11821656093586508),
#   'seizure 1974': np.float64(0.09354326170402105),
#   'logans run 1976': np.float64(0.08579859361170494),
#   'ponette 1996': np.float64(0.07191755781469544),
#   'the remains of the day 1993': np.float64(0.0518759185386477),
#   'the decoy bride 2011': np.float64(0.04207264328225446)},
#  'yellowbrickroad 2010': {'yellowbrickroad 2010': np.float64(1.0),
#   'the wicked lady 1945': np.float64(0.22188007849009161),
#   'extremities 1986': np.float64(0.1268864803313441),
#   'let him have it 1991': np.float64(0.12642790824820282),
#   'the invincible iron man 2007': np.float64(0.09874620280149504),
#   'once upon a honeymoon 1942': np.float64(0.09639875882041571),
#   'amish grace 2010': np.float64(0.08920515501750792),
#   'new dragon gate inn 1992': np.float64(0.07775831396920563),
#   'lured 1947': np.float64(0.062017367294604275),
#   'the wings of eagles 1957': np.float64(0.05220747873491938)},
#  'nocturna 2007': {'nocturna 2007': np.float64(1.0),
#   'hood of horror 2006': np.float64(0.2938318338051653),
#   'the clay bird 2002': np.float64(0.19943242523287097),
#   'taken 2008': np.float64(0.09052090776559474),
#   'if i were you 2006': np.float64(0.08466487815452373),
#   'contempt 1963': np.float64(0.08187924183841255),
#   'maze 2000': np.float64(0.04720021858996293),
#   'wit 2001': np.float64(0.026843521719215335),
#   'how to train your dragon 2010': np.float64(0.009368577886432417),
#   'inglourious basterds 2009': np.float64(0.0076796896840034545)},
#  'madame curie 1943': {'madame curie 1943': np.float64(1.0),
#   'the heats on 1943': np.float64(0.15626907697949854),
#   'the square 2008': np.float64(0.1107273064716533),
#   'girl walks into a bar 2011': np.float64(0.10846522890932808),
#   'little criminals 1995': np.float64(0.10841541709089886),
#   'sweet home alabama 2002': np.float64(0.1019294382875251),
#   'up in the wind 2013': np.float64(0.08097763301789163),
#   'peters friends 1992': np.float64(0.08040302522073695),
#   'kogel-mogel 1988': np.float64(0.07644707871564382),
#   'the adventures of tintin 2011': np.float64(0.07512482264253484)},
#  'the spectacular now 2013': {'the spectacular now 2013': np.float64(1.0),
#   'iron eagle ii 1988': np.float64(0.22755204959542974),
#   'phone call from a stranger 1952': np.float64(0.12982853184369914),
#   'october country 2009': np.float64(0.10217388648599701),
#   'baby on board 1992': np.float64(0.09931185636318118),
#   'mass appeal 1984': np.float64(0.07863001232872624),
#   'state of emergency 2011': np.float64(0.07863001232872624),
#   'addicted to love 1997': np.float64(0.07310968182657174),
#   'julie 1956': np.float64(0.06931323027750436),
#   'days and hours 2004': np.float64(0.06710143863881268)},
#  'spider-man 2002': {'spider-man 2002': np.float64(1.0),
#   'modify 2005': np.float64(0.03534222621266525),
#   'chairman of the board 1998': np.float64(0.033837605424462236),
#   'confessions of a shopaholic 2009': np.float64(0.03318050199088196),
#   'invaders from mars 1986': np.float64(0.03190240033966929),
#   'a christmas story 2 2012': np.float64(0.03115004068421867),
#   'anna karenina 1997': np.float64(0.031051516323502115),
#   'white zombie 1932': np.float64(0.030849224161483946),
#   'goofy movies number one 1933': np.float64(0.030685473870051383),
#   'endgame blueprint for global enslavement 2007': np.float64(0.029893907245934992)},
#  'trust 1990': {'trust 1990': np.float64(1.0),
#   'wonderland 1997': np.float64(0.10205011431883448),
#   'porgy and bess 1959': np.float64(0.0809018821752896),
#   'the wonderful crook 1974': np.float64(0.0727797411725567),
#   'azumi 2 death or love 2005': np.float64(0.06062302448344781),
#   'overnight 2003': np.float64(0.060476250952471666),
#   'the oh in ohio 2006': np.float64(0.06021793163061406),
#   'oppai volleyball 2009': np.float64(0.05959590920305191),
#   'body bags 1993': np.float64(0.05822379293804536),
#   'dragon ball z fusion reborn 1995': np.float64(0.05821041277173333)},
#  'inception 2010': {'inception 2010': np.float64(1.0),
#   'hedda gabler 1962': np.float64(0.023285048808528885),
#   'donovans brain 1953': np.float64(0.023285048808528885),
#   'nemesis 2 - nebula 1995': np.float64(0.023285048808528885),
#   'air bud golden receiver 1998': np.float64(0.022090136898942347),
#   'going all the way 1997': np.float64(0.02201580725123853),
#   'trial by jury 1994': np.float64(0.020279640254825648),
#   'the inn of the sixth happiness 1958': np.float64(0.02004167725074535),
#   'eye in the sky 2007': np.float64(0.019225881614753804),
#   'morgan stewarts coming home 1987': np.float64(0.018628039046823086)},
#  'testament of orpheus 1960': {'testament of orpheus 1960': np.float64(0.9999999999999996),
#   'pathfinder 2007': np.float64(0.09627768015573457),
#   'norte_ the end of history 2013': np.float64(0.07962126655925572),
#   'ambush 1973': np.float64(0.07685678432369447),
#   'super 8 2011': np.float64(0.07494159173891668),
#   'bewitched 1945': np.float64(0.07392528312607438),
#   'liberty 1929': np.float64(0.06834196165516704),
#   'eat a bowl of tea 1989': np.float64(0.061612164767583244),
#   'missionary man 2007': np.float64(0.05369194696288537),
#   'the looney_ looney_ looney bugs bunny movie 1981': np.float64(0.05293745586752163)},
#  'tracers 2015': {'tracers 2015': np.float64(1.0),
#   'joyful noise 2012': np.float64(0.04355724051843768),
#   'blackball 2003': np.float64(0.04051958075357054),
#   'something borrowed 2011': np.float64(0.039607721968704546),
#   'churchill the hollywood years 2004': np.float64(0.03915504742241205),
#   'desperate hours 1990': np.float64(0.03895878028461397),
#   '30 years to life 2003': np.float64(0.037884814366556996),
#   'home room 2002': np.float64(0.03748810380770218),
#   'wendigo 2001': np.float64(0.034435022157509154),
#   'banana joe 1982': np.float64(0.03353037938463632)},
#  'the avengers 2012': {'the avengers 2012': np.float64(0.9999999999999867),
#   'american crude 2008': np.float64(0.04756155149864438),
#   'little fauss and big halsy 1970': np.float64(0.03839001424400079),
#   'hexed 1993': np.float64(0.03118819500727843),
#   'wagons east 1994': np.float64(0.02756673022826872),
#   'ma mre 2004': np.float64(0.025296966582920244),
#   'italianamerican 1974': np.float64(0.02497015978375905),
#   'wild orchid 1989': np.float64(0.02493504569021332),
#   '4 2005': np.float64(0.02493504569021332),
#   'false trail 2011': np.float64(0.023780775749322136)},
#  'harry potter and the chamber of secrets 2002': {'harry potter and the chamber of secrets 2002': np.float64(1.0),
#   'bird of prey 1995': np.float64(0.032285372490850506),
#   'are we there yet 2005': np.float64(0.032285372490850506),
#   'i love you too 2001': np.float64(0.032285372490850506),
#   'young gods 2003': np.float64(0.032285372490850506),
#   'ski patrol 1940': np.float64(0.02814823738519523),
#   'a letter from death row 1998': np.float64(0.028031553256114616),
#   'the italian 2010': np.float64(0.025210640379355165),
#   'call me kuchu 2012': np.float64(0.02394730493756103),
#   'an inconvenient tax 2011': np.float64(0.023299960623099802)},
#  'drowning by numbers 1988': {'drowning by numbers 1988': np.float64(1.0),
#   'tokyo fist 1995': np.float64(0.08087693101032833),
#   'the kid 2000': np.float64(0.07901744265512678),
#   'every man for himself 1980': np.float64(0.07709458901319932),
#   'air force 1943': np.float64(0.07235230892520172),
#   'safe conduct 2002': np.float64(0.07199649817549103),
#   'move over_ darling 1963': np.float64(0.07099880794002189),
#   'shattered 1991': np.float64(0.06973087008581791),
#   'shaolin kung-fu mystagogue 1977': np.float64(0.06356160452261517),
#   'xiu xiu the sent-down girl 1998': np.float64(0.0630445346530002)},
#  'the other woman 2014': {'the other woman 2014': np.float64(1.0),
#   'munyurangabo 2007': np.float64(0.17964393928698885),
#   'the disappearance of eleanor rigby her 2014': np.float64(0.11257918508781617),
#   'target 1985': np.float64(0.10285378442105375),
#   'ceremony 2010': np.float64(0.10254163261037386),
#   'dont tell anyone 1998': np.float64(0.09003996410307435),
#   'tipping the velvet 2002': np.float64(0.08555945841462032),
#   'scooby-doo wrestlemania mystery 2014': np.float64(0.08264666655267039),
#   'the minus man 1999': np.float64(0.07505279005854415),
#   'the offence 1973': np.float64(0.06630205296435043)},
#  'the dark knight 2008': {'the dark knight 2008': np.float64(1.0),
#   'madeas family reunion 2006': np.float64(0.029672676058026815),
#   'jaws the revenge 1987': np.float64(0.029672676058026815),
#   'the crow city of angels 1996': np.float64(0.02373814084642145),
#   'hercules in new york 1969': np.float64(0.02373814084642145),
#   'scream 3 2000': np.float64(0.02373814084642145),
#   'the hitcher 2007': np.float64(0.02373814084642145),
#   'rock of ages 2012': np.float64(0.022330964470857806),
#   'avalanche 1978': np.float64(0.02098175045658257),
#   'fetishes 1996': np.float64(0.02098175045658246)},
#  'harry potter and the philosophers stone 2001': {'harry potter and the philosophers stone 2001': np.float64(1.0),
#   'millennium 1989': np.float64(0.03356016490498748),
#   'the heats on 1943': np.float64(0.03254206608870147),
#   'house on haunted hill 1999': np.float64(0.03115983085654639),
#   'the baby-sitters club 1995': np.float64(0.03059533230333711),
#   'turkish passion 1994': np.float64(0.029210374200734468),
#   'the adventures of pinocchio 1996': np.float64(0.026848131923989937),
#   'first man into space 1959': np.float64(0.025818567097919853),
#   'fast five 2011': np.float64(0.023823864628415015),
#   'mans job 2007': np.float64(0.023598834679802172)},
#  'robin hood 2010': {'robin hood 2010': np.float64(0.9999999999999998),
#   'wild river 1960': np.float64(0.1252448582170299),
#   'attack the block 2011': np.float64(0.06246386238495216),
#   'ice cream man 1995': np.float64(0.06175402271944641),
#   'days of heaven 1978': np.float64(0.049537740461807034),
#   'courageous 2011': np.float64(0.04884348354378354),
#   'good bye_ lenin 2003': np.float64(0.04158252792029449),
#   'men in black 1997': np.float64(0.018936133866396365),
#   'akira 1988': np.float64(0.016753764435328833),
#   'the godfather 1972': np.float64(0.011532713674209494)},
#  'the fifth element 1997': {'the fifth element 1997': np.float64(1.0),
#   'track 29 1988': np.float64(0.034368878169248496),
#   'shock 1977': np.float64(0.03271819725500946),
#   'the gay deceivers 1969': np.float64(0.029613131708436824),
#   'wuthering heights 2003': np.float64(0.028914760258898276),
#   'the forbidden christ 1951': np.float64(0.028132715974884315),
#   'joan of arc 1999': np.float64(0.026996995030482362),
#   'purple butterfly 2003': np.float64(0.02693339778070869),
#   'easy money 2010': np.float64(0.02617455780400757),
#   'd.c. cab 1983': np.float64(0.02617455780400757)},
#  'thoughtcrimes 2003': {'thoughtcrimes 2003': np.float64(1.0),
#   'one direction this is us 2013': np.float64(0.21773242158072692),
#   'begone dull care 1949': np.float64(0.15622669317698867),
#   'smoke on the potato fields 1977': np.float64(0.12104550653376056),
#   'dead mans burden 2012': np.float64(0.11141720290623114),
#   'spider 2002': np.float64(0.09370425713316366),
#   'wind 1992': np.float64(0.09230769230769231),
#   'the secret 2007': np.float64(0.07661308776828735),
#   '35 shots of rum 2009': np.float64(0.07526178090063818),
#   'the boat 1921': np.float64(0.06225430174794666)},
#  'the matrix 1999': {'the matrix 1999': np.float64(1.0),
#   'kung pow enter the fist 2002': np.float64(0.03246411047398723),
#   'motherhood 2009': np.float64(0.03246411047398723),
#   'the adventures of pinocchio 1996': np.float64(0.025971288379189827),
#   'trailer park boys dont legalize it 2014': np.float64(0.025812441088594706),
#   'superman ii 1980': np.float64(0.024431732957112207),
#   'the lesser blessed 2012': np.float64(0.024113735892336896),
#   'the green pastures 1936': np.float64(0.021578701112428655),
#   'bertas motives 1984': np.float64(0.020909722139794473),
#   'the italian 2010': np.float64(0.02028016903635954)},
#  'the bourne supremacy 2004': {'the bourne supremacy 2004': np.float64(0.9999999999999998),
#   'hank and mike 2008': np.float64(0.07581320840379846),
#   'the captains paradise 1953': np.float64(0.06502179046647993),
#   'dressed to kill 1946': np.float64(0.06283212318234122),
#   'drillbit taylor 2008': np.float64(0.05907317606885132),
#   'milius 2013': np.float64(0.05685990630284887),
#   'trouble at timpetill 2008': np.float64(0.05683379383015008),
#   'santos 2008': np.float64(0.05441421484962061),
#   'whats up_ tiger lily 1966': np.float64(0.05441421484962061),
#   'advertising and the end of the world 1998': np.float64(0.0513887998271898)},
#  'batman begins 2005': {'batman begins 2005': np.float64(0.999999999999999),
#   'employee of the month 2006': np.float64(0.07412241772089345),
#   'death warrant 1990': np.float64(0.033622611466225694),
#   'my babys daddy 2004': np.float64(0.032943296764841534),
#   'the returned 2013': np.float64(0.031398785366756554),
#   'the memory keepers daughter 2008': np.float64(0.029118035671325315),
#   '100 girls 2000': np.float64(0.02741047976964528),
#   'the worlds greatest athlete 1973': np.float64(0.02680532456208007),
#   'double wedding 1937': np.float64(0.025568957102531487),
#   'lost youth 1948': np.float64(0.024554483656378134)},
#  'x_ y and zee 1972': {'x_ y and zee 1972': np.float64(1.0),
#   'let it come down the life of paul bowles 1999': np.float64(0.11585688927269844),
#   'generation x 1996': np.float64(0.11428053161268326),
#   'mars attacks 1996': np.float64(0.10127714274653665),
#   'patema inverted 2013': np.float64(0.09663132552468845),
#   'a heart in winter 1992': np.float64(0.0899223855157053),
#   'the fourth state 2012': np.float64(0.0851370785712724),
#   'a taste of honey 1961': np.float64(0.08492503072377333),
#   'captive 2004': np.float64(0.0797381798293696),
#   'zatichis vengeance 1966': np.float64(0.07896274960977712)},
#  'huddersfield 2007': {'huddersfield 2007': np.float64(1.0),
#   'the violent years 1956': np.float64(0.17038855027411948),
#   'thrill ride the science of fun 1997': np.float64(0.12700012700019048),
#   'dont change your husband 1919': np.float64(0.12443420336765099),
#   'les visiteurs du soir 1942': np.float64(0.11731769201708264),
#   'dave attell captain miserable 2007': np.float64(0.10885725171444904),
#   'suite franaise 2014': np.float64(0.10451490688928278),
#   'olive kitteridge 2014': np.float64(0.061705018064682315),
#   'parasomnia 2008': np.float64(0.06024144966768741),
#   'malcolm x 1992': np.float64(0.04444078691701825)},
#  'the princess diaries 2 royal engagement 2004': {'the princess diaries 2 royal engagement 2004': np.float64(0.999999999999999),
#   'partners 1982': np.float64(0.075955452531275),
#   'salmonberries 1991': np.float64(0.06506000486323549),
#   'angele 1934': np.float64(0.0506369683541833),
#   'analyze that 2002': np.float64(0.048795003647426616),
#   'boynton beach club 2005': np.float64(0.04820676840414584),
#   'antoine and colette 1962': np.float64(0.0475131096733199),
#   'things i like_ things i dont like 1989': np.float64(0.04723501677209463),
#   'the secret nation 1989': np.float64(0.04696682183138623),
#   'ten benny 1995': np.float64(0.046633161118844635)},
#  'make way for tomorrow 1937': {'make way for tomorrow 1937': np.float64(1.0),
#   'road to bali 1952': np.float64(0.1418975118028294),
#   'r100 2013': np.float64(0.0865592715571677),
#   'down to the bone 2004': np.float64(0.08224396186997107),
#   'my father and my son 2005': np.float64(0.08160886385685484),
#   'secret beyond the door 1948': np.float64(0.0809882551249771),
#   'cmon man 2012': np.float64(0.07895420339517223),
#   'mississippi mermaid 1969': np.float64(0.07236503841694475),
#   'the magic flute 2006': np.float64(0.06978631577988526),
#   'the last stand 2013': np.float64(0.06786253571934908)},
#  'bad fucking 2013': {'bad fucking 2013': np.float64(1.0),
#   'universal soldier day of reckoning 2012': np.float64(0.1469693845669907),
#   'airborne 1993': np.float64(0.13856406460551018),
#   'running wild 1995': np.float64(0.1326442675663485),
#   'the fountainhead 1949': np.float64(0.125129901920924),
#   'the gladiators 1969': np.float64(0.10432810619146027),
#   'cobra woman 1944': np.float64(0.1039230484541327),
#   'the purge 2013': np.float64(0.09114654303753),
#   'the marquise of o 1976': np.float64(0.0897235446547271),
#   'all the way boys 1972': np.float64(0.08193464903987024)},
#  'games 1967': {'games 1967': np.float64(1.0),
#   'yuki  nina 2009': np.float64(0.15037168948034585),
#   'shockproof 1949': np.float64(0.10623213476947668),
#   'dark command 1940': np.float64(0.1001566171672269),
#   'the skys the limit 1943': np.float64(0.0977193512976684),
#   'zatichis revenge 1965': np.float64(0.09191001531764909),
#   'cats  dogs 2001': np.float64(0.08933250005738369),
#   '1939 hollywoods greatest year 2009': np.float64(0.0854530937843827),
#   'who is killing the great chefs of europe 1978': np.float64(0.08191555672945383),
#   'kauwboy 2012': np.float64(0.07576597098946258)},
#  'rebel without a cause 1955': {'rebel without a cause 1955': np.float64(1.0),
#   'loose change 911 an american coup 2009': np.float64(0.09309175304456452),
#   'my last five girlfriends 2009': np.float64(0.08820549355408303),
#   'zaza 1938': np.float64(0.08759926304692478),
#   'the coast guard 2002': np.float64(0.07187175147570724),
#   'arabian nights 1942': np.float64(0.07168835808806939),
#   'four stories of st. julian 2010': np.float64(0.07136175794719812),
#   'ikigami the ultimate limit 2008': np.float64(0.06890026288999285),
#   'bodies_ rest  motion 1993': np.float64(0.06832368151579382),
#   'lady dragon 1992': np.float64(0.06615412016556221)},
#  'a big hand for the little lady 1966': {'a big hand for the little lady 1966': np.float64(1.0),
#   'the undercover man 1949': np.float64(0.14135069854804394),
#   'maniac 1980': np.float64(0.11534996014569454),
#   'john doe vigilante 2014': np.float64(0.08636670341750607),
#   'playing in the company of men 2003': np.float64(0.07355252980519345),
#   'this happy breed 1944': np.float64(0.0696442538311769),
#   'remo williams the adventure begins... 1985': np.float64(0.06472907152501883),
#   'wings in the dark 1935': np.float64(0.060363272743915064),
#   'seven days in utopia 2011': np.float64(0.057878112706973184),
#   'trust us_ this is all made up 2009': np.float64(0.057416925176321465)},
#  'dream with the fishes 1997': {'dream with the fishes 1997': np.float64(1.0),
#   'mikes murder 1984': np.float64(0.167414699655973),
#   'kisses 2008': np.float64(0.1198204039901507),
#   'whats up_ doc 1972': np.float64(0.11110039592606169),
#   'hit  run 2012': np.float64(0.10480289390403996),
#   'jungle de ikou 1997': np.float64(0.10041928905068676),
#   'hide and seek 2005': np.float64(0.09411764705882353),
#   'colossus the forbin project 1970': np.float64(0.09370514990751855),
#   'fairytale a true story 1997': np.float64(0.09112901991076272),
#   'a matter of life and death 1946': np.float64(0.07631586874921226)},
#  'rat pfink a boo boo 1966': {'rat pfink a boo boo 1966': np.float64(1.0),
#   'fight for your right revisited 2011': np.float64(0.14349920066683497),
#   'jonah who will be 25 in the year 2000 1976': np.float64(0.10792595446884712),
#   'night shift 1982': np.float64(0.10514994558491719),
#   'dead within 2014': np.float64(0.09989599581169395),
#   'red rock west 1993': np.float64(0.09141215602547481),
#   'pride 2014': np.float64(0.07650862242483492),
#   'mugabe and the white african 2009': np.float64(0.06676875252493808),
#   'kaboom 2010': np.float64(0.06021850029028597),
#   'pusher iii im the angel of death 2005': np.float64(0.04915611465907965)},
#  'wrong turn 4 bloody beginnings 2011': {'wrong turn 4 bloody beginnings 2011': np.float64(0.9999999999999999),
#   'beneath the valley of the ultra-vixens 1979': np.float64(0.16572625526497087),
#   'baby boom 1987': np.float64(0.15457193737155983),
#   'on the other side of the tracks 2012': np.float64(0.15333037559998552),
#   'heads 1994': np.float64(0.14187529518897735),
#   'pacific heights 1990': np.float64(0.13054450694575104),
#   'the cocoanuts 1929': np.float64(0.10929886509657227),
#   'no escape 1994': np.float64(0.0900180054018006),
#   'the outlaw and his wife 1918': np.float64(0.06672848092813055),
#   'the passion of joan of arc 1928': np.float64(0.06617926598418711)},
#  'the lord of the rings the fellowship of the ring 2001': {'the lord of the rings the fellowship of the ring 2001': np.float64(0.9999999999999813),
#   'breakin 1984': np.float64(0.025966406658837093),
#   'the center of the world 2001': np.float64(0.025966406658837093),
#   'amandla a revolution in four-part harmony 2002': np.float64(0.022582768100929407),
#   'those daring young men in their jaunty jalopies 1969': np.float64(0.02163544451199506),
#   'bag of bones 2011': np.float64(0.021605356303381562),
#   'somewhere in the night 1946': np.float64(0.02113924864185246),
#   'for queen  country 1988': np.float64(0.02095933687099516),
#   '10_000 bc 2008': np.float64(0.020773125327069764),
#   'spaced invaders 1990': np.float64(0.020773125327069764)},
#  'fury 2014': {'fury 2014': np.float64(1.0),
#   'the beans of egypt_ maine 1994': np.float64(0.04577632885130245),
#   'the wicker man 2006': np.float64(0.03923685330111637),
#   'airport 77 1977': np.float64(0.03564721190874365),
#   'no escape 1994': np.float64(0.03384179371526819),
#   'mr. wu 1927': np.float64(0.03334491343906165),
#   'the fastest gun alive 1956': np.float64(0.03334491343906165),
#   'king solomons mines 2004': np.float64(0.03236875254858129),
#   'bad boys ii 2003': np.float64(0.028581354376338575),
#   'the alarmist 1998': np.float64(0.028294097293006693)},
#  'just like heaven 2005': {'just like heaven 2005': np.float64(0.9999999999999999),
#   'yeh jawaani hai deewani 2013': np.float64(0.110703556532041),
#   'day of the outlaw 1959': np.float64(0.1102164693448009),
#   'the convent 1995': np.float64(0.10380374271141646),
#   'surrogates 2009': np.float64(0.09980525784828886),
#   'the mountain men 1980': np.float64(0.08821621827824622),
#   'whos camus anyway 2005': np.float64(0.08686932669142067),
#   'wind 1992': np.float64(0.07677327526791455),
#   'the savages 2007': np.float64(0.07351351523187177),
#   'the pirates of blood river 1962': np.float64(0.06936944953350399)},
#  'total recall 1990': {'total recall 1990': np.float64(0.9999999999999957),
#   'feeling minnesota 1996': np.float64(0.04875670984206881),
#   'sex lives of the potato men 2004': np.float64(0.046345282995601034),
#   'slappy and the stinkers 1998': np.float64(0.04345868986811208),
#   'captain america 1990': np.float64(0.0401361924197694),
#   'the competition 1980': np.float64(0.03903214808132327),
#   'i melt with you 2011': np.float64(0.0337796394625427),
#   'macarthur 1977': np.float64(0.03230566724548889),
#   'touchy feely 2013': np.float64(0.03207184752150927),
#   'going the distance 2004': np.float64(0.031273869177492086)},
#  'harry potter and the prisoner of azkaban 2004': {'harry potter and the prisoner of azkaban 2004': np.float64(1.0),
#   'silent rage 1982': np.float64(0.03844216303487957),
#   'swimfan 2002': np.float64(0.03586470454242929),
#   'the champ 1979': np.float64(0.03207836693992694),
#   'presspauseplay 2011': np.float64(0.03207836693992694),
#   'houseguest 1995': np.float64(0.026639633754505843),
#   'village of the giants 1965': np.float64(0.025883121027472478),
#   'my favorite martian 1999': np.float64(0.025883121027472478),
#   'hot dog... the movie 1984': np.float64(0.02536017578720373),
#   'duplex 2003': np.float64(0.02511031574515632)},
#  'dream wife 1953': {'dream wife 1953': np.float64(0.9999999999999999),
#   'hearts divided 1936': np.float64(0.13779456365238762),
#   'call me bwana 1963': np.float64(0.12712834523274563),
#   'there be dragons 2011': np.float64(0.0971285862357264),
#   'the wonderful_ horrible life of leni riefenstahl 1993': np.float64(0.08804509063256238),
#   'super troopers 2001': np.float64(0.06911635163761376),
#   'monsters ball 2001': np.float64(0.06574774954783769),
#   'the rules of the game 1939': np.float64(0.05970814340265318),
#   'the era of vampires 2002': np.float64(0.056888012398857435),
#   'knock on wood 1981': np.float64(0.05578560024792012)},
#  'aka tommy chong 2006': {'aka tommy chong 2006': np.float64(0.9999999999999999),
#   'where in the world is osama bin laden 2008': np.float64(0.10286889997472792),
#   'a very social secretary 2005': np.float64(0.09103849893318916),
#   'dantes inferno 2007': np.float64(0.0904084671494414),
# ...
#   'the house on sorority row 1983': np.float64(0.07109215572996375),
#   'breaking out 1999': np.float64(0.06857926664981862)},
#  'the bench 2000': {'the bench 2000': np.float64(1.0),
#   'love with the proper stranger 1963': np.float64(0.12954933037678784),
#   'fric-frac 1939': np.float64(0.11803377817013083),
#   'the 24th day 2004': np.float64(0.10921011245091972),
#   'towelhead 2008': np.float64(0.10467761506390172),
#   'run_ simon_ run 1970': np.float64(0.10070105383574879),
#   'a pain in the ass 2008': np.float64(0.09294286409033647),
#   'immortals 2011': np.float64(0.09137173558097589),
#   'z channel a magnificent obsession 2004': np.float64(0.08556467831935421),
#   'same love_ same rain 1999': np.float64(0.07697370086861777)},
#  'pollock 2000': {'pollock 2000': np.float64(0.9999999999999999),
#   'small change 1976': np.float64(0.10908816839780067),
#   'five 2003': np.float64(0.09798448905826673),
#   'gothika 2003': np.float64(0.08899883189799696),
#   'yatterman 2009': np.float64(0.08781428162823357),
#   'adam  paul 2004': np.float64(0.0868539665415895),
#   'antz 1998': np.float64(0.08210419990401885),
#   'slingshot hip hop 2008': np.float64(0.08000400030002497),
#   'the man who knew too much 1934': np.float64(0.07698906980616138),
#   'kevin nealon now hear me out 2009': np.float64(0.07236634110618101)},
#  'buckskin frontier 1943': {'buckskin frontier 1943': np.float64(0.9999999999999998),
#   'gory gory hallelujah 2003': np.float64(0.11215007691282608),
#   'lucrezia borgia 1935': np.float64(0.09142741045295277),
#   'the east 2013': np.float64(0.0845888852220289),
#   'grotesque 1988': np.float64(0.08109589176365617),
#   'lupin the third sweet lost night 2008': np.float64(0.07029574218647994),
#   'the nasty girl 1990': np.float64(0.06749853254907567),
#   'afterwards 2008': np.float64(0.06672527151654561),
#   'beachhead 1954': np.float64(0.06304883249912807),
#   'stuck 2013': np.float64(0.061736585468577965)},
#  'harry potter and the deathly hallows part 1 2010': {'harry potter and the deathly hallows part 1 2010': np.float64(0.9999999999999949),
#   'an eye for an eye 1981': np.float64(0.032927666365930364),
#   'urusei yatsura 2 beautiful dreamer 1984': np.float64(0.029470325431864675),
#   'fort apache_ the bronx 1981': np.float64(0.025331972171577455),
#   'leprechaun 1993': np.float64(0.024695749774447773),
#   'diary of a cannibal 2007': np.float64(0.023452849003325338),
#   'the adventures of sebastian cole 1998': np.float64(0.023283376175997628),
#   'that evening sun 2009': np.float64(0.02266237423195483),
#   'the borrowers 2011': np.float64(0.022614814107692394),
#   'the headless woman 2008': np.float64(0.02240443917142587)},
#  'bed and board 1970': {'bed and board 1970': np.float64(0.9999999999999999),
#   'a night in the show 1915': np.float64(0.13092781167841538),
#   'gracies choice 2004': np.float64(0.10921300708262971),
#   'funny bones 1995': np.float64(0.09807617561164006),
#   'mommie dearest 1981': np.float64(0.0969287623345313),
#   'executive suite 1954': np.float64(0.09394124215878097),
#   'rolling thunder 1977': np.float64(0.09287369338153384),
#   '50 children the rescue mission of mr. and mrs. kraus 2013': np.float64(0.09099726372498285),
#   'ricochet 1991': np.float64(0.08990340573038302),
#   'thrust in me 1985': np.float64(0.08070932356885097)},
#  'longford 2006': {'longford 2006': np.float64(0.9999999999999999),
#   'the toxic avenger part ii 1989': np.float64(0.11532598634097835),
#   'corn island 2014': np.float64(0.10439983292031152),
#   'better things 2008': np.float64(0.10356579304153568),
#   'so undercover 2012': np.float64(0.09194260527375286),
#   'we all loved each other so much 1974': np.float64(0.08100951188521843),
#   'american vagabond 2013': np.float64(0.07549858028613954),
#   'kalifornia 1993': np.float64(0.07214139140232989),
#   'gme. 2003': np.float64(0.06438540560334605),
#   'ronin 1998': np.float64(0.05990118464898997)},
#  'captive women 1952': {'captive women 1952': np.float64(1.0),
#   'mayor of the sunset strip 2003': np.float64(0.14955230528038554),
#   'open up to me 2013': np.float64(0.1241302561548403),
#   'gangs of wasseypur 2012': np.float64(0.11580292956166638),
#   '4 little girls 1997': np.float64(0.11374657965622859),
#   'nightbreed 1990': np.float64(0.10742368705033323),
#   'the sundowners 1960': np.float64(0.10169491525423724),
#   'stargate continuum 2008': np.float64(0.0957167909875708),
#   'get out your handkerchiefs 1978': np.float64(0.093031641953778),
#   'un chien andalou 1929': np.float64(0.08519822595285076)},
#  'repo man 1984': {'repo man 1984': np.float64(1.0),
#   'hangmen also die 1943': np.float64(0.09761543129093264),
#   'the bostonians 1984': np.float64(0.09483906757591565),
#   'how she move 2008': np.float64(0.08384845509334604),
#   'the danube exodus 1998': np.float64(0.07780018007115641),
#   'journey to the beginning of time 1955': np.float64(0.07502069948418932),
#   'the white haired witch of lunar kingdom 2014': np.float64(0.06773286157977632),
#   'one hundred mornings 2009': np.float64(0.06675015657623451),
#   'the appeared 2008': np.float64(0.06288634132000948),
#   'the wild hunt 2009': np.float64(0.05937420953898642)},
#  'the place promised in our early days 2004': {'the place promised in our early days 2004': np.float64(1.0),
#   'all the way home 1963': np.float64(0.10077653036732603),
#   'the fighting sullivans 1944': np.float64(0.09945203708388539),
#   'trouble at timpetill 2008': np.float64(0.08739516627288868),
#   'lassie come home 1943': np.float64(0.07139064005133933),
#   'sweet november 2001': np.float64(0.07070085923669134),
#   'karlsson on the roof 1974': np.float64(0.06992769226994289),
#   'valley girl 1983': np.float64(0.06526047510711452),
#   'the great ziegfeld 1936': np.float64(0.06501129330710442),
#   'prowl 2010': np.float64(0.06115528034566875)},
#  'celeste  jesse forever 2012': {'celeste  jesse forever 2012': np.float64(1.0),
#   'hope floats 1998': np.float64(0.21927768296811767),
#   'rocketman 1997': np.float64(0.19407416991319404),
#   'pray the devil back to hell 2008': np.float64(0.13957716335942316),
#   'land of the dead 2005': np.float64(0.11819087006064355),
#   'a letter from death row 1998': np.float64(0.11187625870603635),
#   'dont move 2004': np.float64(0.09726249080027327),
#   'remember me_ my love 2003': np.float64(0.07130740328122931),
#   'the iron rose 1973': np.float64(0.06779661016949157),
#   'life and debt 2003': np.float64(0.05810133235750636)},
#  'redes 1936': {'redes 1936': np.float64(1.0),
#   'the anarchist cookbook 2002': np.float64(0.3922322702763681),
#   'out late 2011': np.float64(0.156114278450193),
#   'beauty and the boss 1932': np.float64(0.12009611535381537),
#   'rage 2014': np.float64(0.11793204413121583),
#   'a star is born 1976': np.float64(0.09730085108210396),
#   'duel in the sun 1946': np.float64(0.09054490911587254),
#   'aurora borealis 2005': np.float64(0.08869685939836236),
#   'norma jean  marilyn 1996': np.float64(0.07924288517503275),
#   'the hard corps 2006': np.float64(0.07517640165488826)},
#  'antarctica 1983': {'antarctica 1983': np.float64(1.0),
#   'the living idol 1957': np.float64(0.12893167424406082),
#   'get real 1998': np.float64(0.10818558060197891),
#   'mg 1988': np.float64(0.09607689228305227),
#   'watch on the rhine 1943': np.float64(0.07236272269866328),
#   'the lawless breed 1953': np.float64(0.0658145181714418),
#   'my favorite wife 1940': np.float64(0.05797409637607476),
#   'largent 1983': np.float64(0.05013071917732281),
#   'master and commander the far side of the world 2003': np.float64(0.023431896740566227),
#   'finding nemo 2003': np.float64(0.017741543180411656)},
#  'whisper 2007': {'whisper 2007': np.float64(1.0),
#   'godzilla vs. biollante 1989': np.float64(0.11976369980933921),
#   'the disappearance of eleanor rigby her 2014': np.float64(0.10693090271739547),
#   'go west 1940': np.float64(0.1023785449184903),
#   'prozac nation 2001': np.float64(0.0922313192852019),
#   'hail caesar 1994': np.float64(0.0914885046197792),
#   'russell peters the green card tour 2011': np.float64(0.09071032165242765),
#   'extracted 2012': np.float64(0.07512531337059503),
#   'sexual dependency 2003': np.float64(0.06719412301104977),
#   'spellbound 1945': np.float64(0.06255921184647839)},
#  'madadayo 1993': {'madadayo 1993': np.float64(1.0),
#   'ollie hopnoodles haven of bliss 1988': np.float64(0.1160517706371319),
#   'the anna nicole smith story 2007': np.float64(0.09249945801257609),
#   'closer to the moon 2013': np.float64(0.09017555529709931),
#   'cyclo 1995': np.float64(0.08315082916000427),
#   'der letzte schne herbsttag 2010': np.float64(0.07288942961247935),
#   'the greatest 2009': np.float64(0.06932841119086863),
#   'the chosen 1981': np.float64(0.06735424270436285),
#   'sniper 2 2002': np.float64(0.055048188256318076),
#   'get shorty 1995': np.float64(0.05437272478270372)},
#  'captain phillips 2013': {'captain phillips 2013': np.float64(1.0),
#   'julie 1956': np.float64(0.09712785319809114),
#   'cowards bend the knee 2003': np.float64(0.08732508837128772),
#   'another womans life 2012': np.float64(0.0810909153947228),
#   'the woodmans 2011': np.float64(0.08022300904047808),
#   'maradona_ the hand of god 2007': np.float64(0.07770228255847289),
#   'starry starry night 2011': np.float64(0.07652787317933807),
#   'kathleen 1941': np.float64(0.07075004378213046),
#   'the blind menace 1960': np.float64(0.06844861064099317),
#   'the mountain 1956': np.float64(0.06679900411777095)},
#  'thr3e 2006': {'thr3e 2006': np.float64(1.0),
#   'mayerling 1968': np.float64(0.16561869174520982),
#   'the john garfield story 2003': np.float64(0.14073344364024964),
#   'black knight 2001': np.float64(0.14002800840280094),
#   'the wedding party 1969': np.float64(0.10713431680111607),
#   'dont look back 1967': np.float64(0.1045101550762797),
#   'bustin down the door 2008': np.float64(0.10415395333694744),
#   'hi-yo silver 1940': np.float64(0.10169856723618431),
#   'the perfect human 1967': np.float64(0.08891787425369735),
#   'things we lost in the fire 2007': np.float64(0.07346718851514344)},
#  'the golden dream 2013': {'the golden dream 2013': np.float64(1.0),
#   'otaku 1994': np.float64(0.12719260014977873),
#   'daddy long legs 1955': np.float64(0.09946717954563344),
#   'true blue 1996': np.float64(0.09946717954563344),
#   'baby the rain must fall 1965': np.float64(0.09504969130435148),
#   'chimpanzee 2012': np.float64(0.09080069661426649),
#   'unconscious 2004': np.float64(0.06512896090258358),
#   'bed and board 1970': np.float64(0.06441031760728622),
#   'ruthless people 1986': np.float64(0.05194853871537353),
#   'the edge 1997': np.float64(0.05152825408582895)},
#  'cinderella man 2005': {'cinderella man 2005': np.float64(0.9999999999999999),
#   'grand isle 1991': np.float64(0.1433164917687728),
#   'los rollos perdidos de pancho villa 2003': np.float64(0.07981504340066381),
#   'all the way home 1963': np.float64(0.0763177786621918),
#   'nothings all bad 2010': np.float64(0.07217019323655549),
#   'french roast 2008': np.float64(0.0713887450683921),
#   'four nights of a dreamer 1971': np.float64(0.07038085338176359),
#   'joe 1970': np.float64(0.06702015279596485),
#   'painted fire 2002': np.float64(0.06621451835231018),
#   'i origins 2014': np.float64(0.06349125725899496)},
#  'exodus 1960': {'exodus 1960': np.float64(1.0),
#   'pu-239 2006': np.float64(0.08659154800853919),
#   'lucy 2003': np.float64(0.0845327866672051),
#   'sky captain and the world of tomorrow 2004': np.float64(0.080366016667613),
#   'whatever it takes 2000': np.float64(0.07908097149197779),
#   'coffee town 2013': np.float64(0.07840792970779298),
#   'ingrid 2010': np.float64(0.07145531141234596),
#   'ricky rapper and the bicycle thief 2010': np.float64(0.06888315463906336),
#   'gambling city 1975': np.float64(0.06872351791314002),
#   'light is calling 2004': np.float64(0.06328660392433116)},
#  'starsuckers 2009': {'starsuckers 2009': np.float64(0.9999999999999998),
#   'it started in naples 1960': np.float64(0.15790840679034446),
#   'i cant sleep 1994': np.float64(0.14325741582673424),
#   'the wildcat 1921': np.float64(0.13098532273439523),
#   'the night they raided minskys 1968': np.float64(0.12210183437682387),
#   'the holy innocents 1984': np.float64(0.1019294382875251),
#   'fahrenheit 451 1966': np.float64(0.08172536479247938),
#   'midnight cowboy 1969': np.float64(0.07690993104979915),
#   'ugly_ dirty and bad 1976': np.float64(0.07668710153141078),
#   'wristcutters a love story 2006': np.float64(0.05355648743919783)},
#  'vice 2015': {'vice 2015': np.float64(0.9999999999999988),
#   'coco chanel  igor stravinsky 2009': np.float64(0.0420116152966209),
#   'harishchandrachi factory 2009': np.float64(0.039620578725951705),
#   'bending the rules 2012': np.float64(0.033262632979516926),
#   'hidden agenda 2001': np.float64(0.03321618757685829),
#   'the wise kids 2011': np.float64(0.03300366979956515),
#   'right america  feeling wronged 2009': np.float64(0.03229076349992377),
#   'the watcher 2000': np.float64(0.03203749869945005),
#   'whiteout 2009': np.float64(0.03203749869945005),
#   'peacock 2010': np.float64(0.03196076206542675)},
#  'hyenas 1992': {'hyenas 1992': np.float64(0.9999999999999998),
#   'full moon in blue water 1988': np.float64(0.19156525704423033),
#   'ali zaoua prince of the streets 2000': np.float64(0.16673615454405166),
#   'the woman on pier 13 1949': np.float64(0.12394207749905317),
#   'the woman in white 1948': np.float64(0.10909541725914829),
#   'janie jones 2010': np.float64(0.10581006798365178),
#   'alice doesnt live here anymore 1974': np.float64(0.10167228174408427),
#   'mr. klein 1976': np.float64(0.08215180532661737),
#   'the simple-minded murderer 1982': np.float64(0.0782061887005775),
#   'blonde venus 1932': np.float64(0.07766868275249506)},
#  'theres only one sun 2007': {'theres only one sun 2007': np.float64(1.0),
#   'possession 2009': np.float64(0.22063893940587664),
#   'wild seven 2006': np.float64(0.19959498361736527),
#   'visit to a small planet 1960': np.float64(0.18547162802488582),
#   'mother earth 1968': np.float64(0.18293182415200948),
#   'the suitor 1962': np.float64(0.1256380926484122),
#   'thunderpants 2002': np.float64(0.12190439333572467),
#   'arctic tale 2007': np.float64(0.11344950128307119),
#   'immortals 2011': np.float64(0.11328823680740419),
#   'bhutto 2010': np.float64(0.11258675491219972)},
#  'the best exotic marigold hotel 2011': {'the best exotic marigold hotel 2011': np.float64(1.0),
#   'the umbrella woman 1987': np.float64(0.1269591790297564),
#   'rv 2006': np.float64(0.10489830101982134),
#   'ill never forget whatsisname 1967': np.float64(0.09800245962037257),
#   'the auntie from chicago 1957': np.float64(0.09575860952087223),
#   'android 1982': np.float64(0.08795989942670845),
#   'city of women 1980': np.float64(0.08533363674235894),
#   'chilly scenes of winter 1979': np.float64(0.08242217033287502),
#   'the magic of ordinary days 2005': np.float64(0.07744437317055619),
#   'love me tonight 1932': np.float64(0.07714593516963442)},
#  'papillon 1973': {'papillon 1973': np.float64(1.0),
#   'guilty by suspicion 1991': np.float64(0.0669506937387323),
#   'the wages of fear 1953': np.float64(0.05979909360853075),
#   'fast life 1932': np.float64(0.05872755956326314),
#   'because youre mine 1952': np.float64(0.05596595507135904),
#   'menace ii society 1993': np.float64(0.05343088030312515),
#   'noise 2004': np.float64(0.05235135730015228),
#   'the kidnappers 1953': np.float64(0.05189010287024454),
#   'get hard 2015': np.float64(0.05105497393871439),
#   'mall 2014': np.float64(0.05038993108215828)},
#  'princess mononoke 1997': {'princess mononoke 1997': np.float64(0.9999999999999809),
#   'camp rock 2008': np.float64(0.03520428470668446),
#   '10_000 bc 2008': np.float64(0.03520428470668446),
#   'death before dishonor 1987': np.float64(0.029291735452150136),
#   'the ghost of frankenstein 1942': np.float64(0.028163427765347637),
#   'devil doll 1964': np.float64(0.028163427765347637),
#   'two girls and a sailor 1944': np.float64(0.023138617025622255),
#   'mamas boy 2007': np.float64(0.02284355638004132),
#   'desperate hours 1990': np.float64(0.022530742212278132),
#   'shockproof 1949': np.float64(0.022516736154756023)},
#  ...}

# %%
def get_movie_recommendations(movie_title, movie_sim_dict, n=5):
    if movie_title not in movie_sim_dict:
        return "Movie not found in the database."
    
    similar_movies = movie_sim_dict[movie_title]
    recommendations = sorted(similar_movies.items(), key=lambda x: x[1], reverse=True)[:n]
    
    return [movie for movie, similarity in recommendations]

# %%
model_filename = "knn.pkl"

# Save the movie similarity dictionary to a file
with open(model_filename, "wb") as file:
    pickle.dump(movie_sim_dict, file)

print(f"Model saved to {model_filename}")

# %%
# Example usage
movie_title = "faraway 2001"
recommendations = get_movie_recommendations(movie_title, movie_sim_dict)
print(f"Recommendations for {movie_title}:")
for i, movie in enumerate(recommendations, 1):
    print(f"{i}. {movie}")
# Out:
# Recommendations for faraway 2001:
# 1. M
# 2. o
# 3. v
# 4. i
# 5. e
# 6.
# 7. n
# 8. o
# 9. t
# 10.
# 11. f
# 12. o
# 13. u
# 14. n
# 15. d
# 16.
# 17. i
# 18. n
# 19.
# 20. t
# 21. h
# 22. e
# 23.
# 24. d
# 25. a
# 26. t
# 27. a
# 28. b
# 29. a
# 30. s
# 31. e
# 32. .

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import pickle

def load_data():
    # Load your data here
    # Assume we have a DataFrame with columns: user_id, movie_id, rating
    return pd.read_csv(RATINGS_FILE)

def create_user_item_matrix(df):
    # Create a user-item matrix
    user_item_matrix = df.pivot_table(index='user_id', columns='movie_title', values='rating', aggfunc='mean').fillna(0)
    return user_item_matrix

def train_knn_model(user_item_matrix, n_neighbors=5):
    # Create a sparse matrix
    user_item_sparse = csr_matrix(user_item_matrix.values)
    
    # Train KNN model
    model = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=n_neighbors, n_jobs=-1)
    model.fit(user_item_sparse)
    
    return model, user_item_sparse

def get_movie_recommendations(user_id, model, user_item_matrix, user_item_sparse, n_recommendations=5):
    if user_id not in user_item_matrix.index:
        return "User not found in the database."
    
    # Find the user's index
    user_index = user_item_matrix.index.get_loc(user_id)
    
    # Find similar users
    distances, indices = model.kneighbors(user_item_sparse[user_index].reshape(1, -1), n_neighbors=n_recommendations+1)
    
    # Get the movies watched by similar users
    similar_users_movies = user_item_matrix.iloc[indices.flatten()[1:]]
    
    # Get movies the user hasn't watched
    user_movies = user_item_matrix.loc[user_id]
    unwatched_movies = user_movies[user_movies == 0].index
    
    # Calculate the average rating for unwatched movies among similar users
    recommendations = similar_users_movies[unwatched_movies].mean().sort_values(ascending=False)
    
    return recommendations.head(n_recommendations)

# Main execution
df = load_data()
user_item_matrix = create_user_item_matrix(df)
knn_model, user_item_sparse = train_knn_model(user_item_matrix)

# Example usage
user_id = 1  # Replace with an actual user ID from your dataset
recommendations = get_movie_recommendations(user_id, knn_model, user_item_matrix, user_item_sparse)
print(f"Recommendations for user {user_id}:")
print(recommendations)

# Save the model
model_data = {
    'knn_model': knn_model,
    'user_item_matrix': user_item_matrix,
    'user_item_sparse': user_item_sparse
}

with open('knn_movie_recommender.pkl', 'wb') as f:
    pickle.dump(model_data, f)

print("Model saved successfully!")
# Out:
# /tmp/ipykernel_15145/3305635803.py:14: PerformanceWarning: The following operation may generate 5635981112 cells in the resulting pandas object.
#   user_item_matrix = df.pivot_table(index='user_id', columns='movie_title', values='rating', aggfunc='mean').fillna(0)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[26], line 51
#      49 # Main execution
#      50 df = load_data()
# ---> 51 user_item_matrix = create_user_item_matrix(df)
#      52 knn_model, user_item_sparse = train_knn_model(user_item_matrix)
#      54 # Example usage
#
# Cell In[26], line 14, in create_user_item_matrix(df)
#      12 def create_user_item_matrix(df):
#      13     # Create a user-item matrix
# ---> 14     user_item_matrix = df.pivot_table(index='user_id', columns='movie_title', values='rating', aggfunc='mean').fillna(0)
#      15     return user_item_matrix
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
#    9517         dropna=dropna,
#    9518         margins_name=margins_name,
#    9519         observed=observed,
#    9520         sort=sort,
#    9521     )
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:203, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     201         else:
#     202             to_unstack.append(name)
# --> 203     table = agged.unstack(to_unstack, fill_value=fill_value)
#     205 if not dropna:
#     206     if isinstance(table.index, MultiIndex):
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/frame.py:9928, in DataFrame.unstack(self, level, fill_value, sort)
#    9864 """
#    9865 Pivot a level of the (necessarily hierarchical) index labels.
#    9866
#    (...)
#    9924 dtype: float64
#    9925 """
#    9926 from pandas.core.reshape.reshape import unstack
# -> 9928 result = unstack(self, level, fill_value, sort)
#    9930 return result.__finalize__(self, method="unstack")
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:504, in unstack(obj, level, fill_value, sort)
#     502 if isinstance(obj, DataFrame):
#     503     if isinstance(obj.index, MultiIndex):
# --> 504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
#     506         return obj.T.stack(future_stack=True)
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:537, in _unstack_frame(obj, level, fill_value, sort)
#     535     return obj._constructor_from_mgr(mgr, axes=mgr.axes)
#     536 else:
# --> 537     return unstacker.get_result(
#     538         obj._values, value_columns=obj.columns, fill_value=fill_value
#     539     )
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:238, in _Unstacker.get_result(self, values, value_columns, fill_value)
#     235 if value_columns is None and values.shape[1] != 1:  # pragma: no cover
#     236     raise ValueError("must pass column labels for multi-column data")
# --> 238 values, _ = self.get_new_values(values, fill_value)
#     239 columns = self.get_new_columns(value_columns)
#     240 index = self.new_index
#
# File /home/Recomm-project/imdbvenv/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:289, in _Unstacker.get_new_values(self, values, fill_value)
#     287     else:
#     288         dtype, fill_value = maybe_promote(dtype, fill_value)
# --> 289         new_values = np.empty(result_shape, dtype=dtype)
#     290         new_values.fill(fill_value)
#     292 name = dtype.name
#
# MemoryError: Unable to allocate 42.0 GiB for an array with shape (212294, 26548) and data type float64

# %%
import pickle

# Load the model
with open('knn_movie_recommender.pkl', 'rb') as f:
    loaded_model_data = pickle.load(f)

knn_model = loaded_model_data['knn_model']
user_item_matrix = loaded_model_data['user_item_matrix']
user_item_sparse = loaded_model_data['user_item_sparse']

# Get recommendations for a user
user_id = 1  # Replace with an actual user ID
recommendations = get_movie_recommendations(user_id, knn_model, user_item_matrix, user_item_sparse)
print(f"Recommendations for user {user_id}:")
print(recommendations)
