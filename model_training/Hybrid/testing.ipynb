# %%
# example_usage.py
from recommend import load_models, hybrid_recommend, get_weights
import pandas as pd

def get_recommendations(user_id, cf_model, user_profiles, movie_profiles, movie_list, ratings_df, popularity_model, top_n):
    alpha, beta = get_weights(user_id, ratings_df)
    print(alpha, beta)
    if user_id not in ratings_df['user_id'].values and user_id not in user_profiles:
        print("Cold-start user: returning popularity-based recommendations.")
        return popularity_model[:top_n]

    return hybrid_recommend(
        user_id=user_id,
        cf_model=cf_model,
        user_profiles=user_profiles,
        movie_profiles=movie_profiles,
        movie_list=movie_list,
        alpha=alpha,
        beta=beta,
        top_n=top_n
    )


# Load precomputed models and profiles
cf_model, popularity_model, user_profiles, movie_profiles = load_models()

ratings_df = pd.read_csv("processed_data/hybrid_model_data.csv")

# Available movies
movie_list = list(movie_profiles.keys())

# Test user ID
user_id = "301905"

# Run recommendation
recommended_movie_ids = get_recommendations(
    user_id=int(user_id),
    cf_model=cf_model,
    user_profiles=user_profiles,
    movie_profiles=movie_profiles,
    movie_list=movie_list,
    ratings_df=ratings_df,
    popularity_model=popularity_model,
    top_n=10
)

print(f"Top recommendations for user {user_id}:")
print(recommended_movie_ids)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3047, in run_cell
#     result = self._run_cell(
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3102, in _run_cell
#     result = runner(coro)
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3306, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3489, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3549, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/gc/8gz99sqd4790gsdvvnxnmjm00000gn/T/ipykernel_77855/1585163514.py", line 2, in <module>
#     from recommend import load_models, hybrid_recommend, get_weights
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/initial_model_prep/recommend.py", line 3, in <module>
#     from surprise import SVD
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/surprise/__init__.py", line 6, in <module>
#     from .prediction_algorithms import (
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/surprise/prediction_algorithms/__init__.py", line 23, in <module>
#     from .algo_base import AlgoBase
#   File "/Users/vikramharikrishnan/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/surprise/prediction_algorithms/algo_base.py", line 8, in <module>
#     from .. import similarities as sims
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 # example_usage.py
# ----> 2 from recommend import load_models, hybrid_recommend, get_weights
#       3 import pandas as pd
#       5 def get_recommendations(user_id, cf_model, user_profiles, movie_profiles, movie_list, ratings_df, popularity_model, top_n):
#
# File ~/Documents/UIC/RAI/Netflicks/initial_model_prep/recommend.py:3
#       1 import pickle
#       2 import numpy as np
# ----> 3 from surprise import SVD
#       4 from sklearn.metrics.pairwise import cosine_similarity
#       6 def load_models():
#
# File ~/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/surprise/__init__.py:6
#       2 from .builtin_datasets import get_dataset_dir
#       4 from .dataset import Dataset
# ----> 6 from .prediction_algorithms import (
#       7     AlgoBase,
#       8     BaselineOnly,
#       9     CoClustering,
#      10     KNNBaseline,
#      11     KNNBasic,
#      12     KNNWithMeans,
#      13     KNNWithZScore,
#      14     NMF,
#      15     NormalPredictor,
#      16     Prediction,
#      17     PredictionImpossible,
#      18     SlopeOne,
#      19     SVD,
#      20     SVDpp,
#      21 )
#      22 from .reader import Reader
#      23 from .trainset import Trainset
#
# File ~/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/surprise/prediction_algorithms/__init__.py:23
#       1 """
#       2 The :mod:`prediction_algorithms` package includes the prediction algorithms
#       3 available for recommendation.
#    (...)     20     co_clustering.CoClustering
#      21 """
# ---> 23 from .algo_base import AlgoBase
#      24 from .baseline_only import BaselineOnly
#      25 from .co_clustering import CoClustering
#
# File ~/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/surprise/prediction_algorithms/algo_base.py:8
#       1 """
#       2 The :mod:`surprise.prediction_algorithms.algo_base` module defines the base
#       3 class :class:`AlgoBase` from which every single prediction algorithm has to
#       4 inherit.
#       5 """
#       6 import heapq
# ----> 8 from .. import similarities as sims
#       9 from .optimize_baselines import baseline_als, baseline_sgd
#      10 from .predictions import Prediction, PredictionImpossible
#
# File ~/Documents/UIC/RAI/Netflicks/.venv/lib/python3.12/site-packages/surprise/similarities.pyx:1, in init surprise.similarities()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).
